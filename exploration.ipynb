# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %% [markdown]
# ### Woolworths weekly catalogue scraper

# %%
# api endpoint to get category list (use "view" endpoint)
url_view = "https://embed.salefinder.com.au/productlist/view/62467/"

# parameters for the request
params = {
    'locationId': '4679',
    'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
    'saleGroup': '0',
    'rows_per_page': '10',
}

# headers to make our request look like a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
    'Accept': '*/*',
}

# fetch the main catalogue page
response = requests.get(url_view, params=params, headers=headers)
json_text = response.text.strip()[1:-1]
data = json.loads(json_text)

print(f"Fetched: {data['saleName']}")
print(f"Valid: {data['startDate']} to {data['endDate']}\n")

# parse the HTML to extract categories
soup = BeautifulSoup(data['content'], 'html.parser')
categories = {}

for link in soup.find_all('a', class_='sf-navcategory-link'):
    href = link.get('href', '')
    if 'categoryId=' in href:
        category_id = href.split('categoryId=')[1].split('&')[0]
        category_name = link.text.strip()
        categories[category_id] = category_name
# Out:
# Fetched: Weekly Catalogue NSW
# Valid: 2025-12-03T00:00:00 to 2025-12-09T23:59:59

# %%
url_category = "https://embed.salefinder.com.au/productlist/category/62467/"

# list to store ALL products from ALL categories
all_products = []

# loop through each category
for category_id, category_name in categories.items():
    
    # parameters for this specific category
    params = {
        'locationId': '4679',
        'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
        'saleGroup': '0',
        'categoryId': category_id, 
        'rows_per_page': '500',
    }
    
    # api request
    response = requests.get(url_category, params=params, headers=headers)
    json_text = response.text.strip()[1:-1]
    data = json.loads(json_text)
    
    # parse
    soup = BeautifulSoup(data['content'], 'html.parser')
    
    # extract products
    for product in soup.find_all('div', class_='shelfProductStamp'):
        name_tag = product.find('span', class_='sf-item-heading')
        sale_price_tag = product.find('span', class_='sf-pricedisplay')
        savings_tag = product.find('span', class_='sf-regprice')
        
        if not name_tag or not sale_price_tag:
            continue
        
        name = name_tag.text.strip()
        sale_price = sale_price_tag.text.strip()
        stock_code = product.get('data-stockcode')
        
        sale_value = float(sale_price.replace('$', '').replace(',', ''))    
            
        if savings_tag:
            savings = savings_tag.text.strip()
            savings_value = float(savings.replace('$', ''))
            original_value = sale_value + savings_value
        else:
            savings_value = 0.0
            original_value = sale_value
        
        all_products.append({
            'category': category_name,
            'stock_code': stock_code,
            'name': name,
            'sale_price': sale_value,
            'original_price': original_value,
            'savings': savings_value
        })
    
    time.sleep(0.3) 

# Create DataFrame
df = pd.DataFrame(all_products)

# %%
df = pd.DataFrame(all_products)

df.groupby('category').first().reset_index()
# Out:
#                       category stock_code  \
# 0                         Baby      20391
# 1                       Bakery      91895
# 2                       Baking     893892
# 3                       Beauty    6030444
# 4            Biscuits & Snacks     384250
# 5              Breakfast Foods     701706
# 6         Canned & Packet food    6022474
# 7                     Clothing    6030298
# 8                   Condiments
# 9                Confectionery     108635
# 10  Cooking, Seasoning & Gravy     220015
# 11                       Dairy     311844
# 12              Deli & Chilled     311844
# 13                    Desserts      91895
# 14                      Drinks     159798
# 15                 Frozen Food    6005422
# 16          Fruit & Vegetables     143168
# 17          Health & Wellbeing     905571
# 18                Health Foods     641258
# 19              Home & Outdoor     430270
# 20          Household Cleaning     240449
# 21              Jams & Spreads      48462
# 22                        Meat     170438
# 23    Papergoods, Wraps & Bags      19787
# 24                    Pet care    6006759
# 25                     Seafood    6025795
# 26          Stationery & Media     430270
# 27                  Toiletries
#
#                                                  name  sale_price  \
# 0                         Huggies Baby Wipes Pk 72-80        2.50
# 1                       Woolworths Large Pavlova Base        7.50
# 2   Betty Crocker Cake or Cupcake Baking Mixes 370...        3.00
# 3             The Kind Collective Mini Trio Sweet Fix        7.00
# 4                Arnott’s Jatz Crackers Biscuits 225g        2.00
# 5   Kellogg’s Nutri-Grain 290g or Froot Loops Cere...        3.50
# 6                      Thomas Dux Salmon Gravlax 100g        8.00
# 7              Christmas Licensed Socks Pk 2 Assorted        7.00
# 8       Woolworths Citrus, Honey & Mustard Glaze 150g        4.00
# 9                     Cadbury Christmas Stocking 180g        6.00
# 10                        Carbonell Olive Oil 1 Litre       13.00
# 11                  Thomas Dux Brie or Camembert 125g        2.70
# 12                  Thomas Dux Brie or Camembert 125g        2.70
# 13                      Woolworths Large Pavlova Base        7.50
# 14          Kirks Soft Drink Can Varieties 10 x 375ml        7.50
# 15     McCain Air Fryer Chips 750g – From the Freezer        2.90
# 16                            Australian R2E2 Mangoes        2.50
# 17        Blackmores Super Magnesium+ Tablets Pk 180~       22.50
# 18  Vege Deli Crisps 100g – From the Health Food A...        3.25
# 19   Energizer Max Alkaline Batteries AA or AAA Pk 24       15.00
# 20             Vileda Microfibre Recycled Cloths Pk 3        3.00
# 21                          Devondale Spreadable 500g        6.70
# 22                 Woolworths Australian Half Leg Ham        8.00
# 23                      Handee Ultra Paper Towel Pk 2        2.15
# 24                         Friskies Dry Cat Food 700g        3.30
# 25  Woolworths Frozen Cooked Cocktail Tiger Prawns...       25.00
# 26   Energizer Max Alkaline Batteries AA or AAA Pk 24       15.00
# 27                             Hot Wheels Bubble Bath        7.00
#
#     original_price  savings
# 0              5.0     2.50
# 1              7.5     0.00
# 2              6.0     3.00
# 3             10.0     3.00
# 4              4.0     2.00
# 5              7.0     3.50
# 6              8.0     0.00
# 7             10.0     3.00
# 8              4.0     0.00
# 9              8.0     2.00
# 10            26.0    13.00
# 11             2.7     0.00
# 12             2.7     0.00
# 13             7.5     0.00
# 14            15.0     7.50
# 15             5.8     2.90
# 16             2.5     0.00
# 17            45.0    22.50
# 18             6.5     3.25
# 19            30.0    15.00
# 20             6.0     3.00
# 21            14.2     7.50
# 22             8.0     0.00
# 23             4.3     2.15
# 24             5.6     2.30
# 25            25.0     0.00
# 26            30.0    15.00
# 27            10.0     3.00

# %% [markdown]
# ### Australia food guidelines

# %% [markdown]
# https://www.eatforhealth.gov.au/food-essentials/how-much-do-we-need-each-day/recommended-number-serves-adults

# %%
# converting the table above into a df
dietary_guidelines = {
    'Group': [
        'Men 19-50',
        'Men 51-70', 
        'Men 70+',
        'Women 19-50',
        'Women 51-70',
        'Women 70+',
        'Pregnant',
        'Lactating'
    ],
    'Vegetables & Legumes': [6, 5.5, 5, 5, 5, 5, 5, 7.5],
    'Fruit': [2, 2, 2, 2, 2, 2, 2, 2],
    'Grains (Wholegrain)': [6, 6, 4.5, 6, 4, 3, 8.5, 9],
    'Lean Meat & Alternatives': [3, 2.5, 2.5, 2.5, 2, 2, 3.5, 2.5],
    'Dairy (Reduced Fat)': [2.5, 2.5, 3.5, 2.5, 4, 4, 2.5, 2.5],
    'Additional Serves Range': ['0-3', '0-2.5', '0-2.5', '0-2.5', '0-2.5', '0-2', '0-2.5', '0-2.5']
}

df_guidelines = pd.DataFrame(dietary_guidelines)

df_guidelines
# Out:
#          Group  Vegetables & Legumes  Fruit  Grains (Wholegrain)  \
# 0    Men 19-50                   6.0      2                  6.0
# 1    Men 51-70                   5.5      2                  6.0
# 2      Men 70+                   5.0      2                  4.5
# 3  Women 19-50                   5.0      2                  6.0
# 4  Women 51-70                   5.0      2                  4.0
# 5    Women 70+                   5.0      2                  3.0
# 6     Pregnant                   5.0      2                  8.5
# 7    Lactating                   7.5      2                  9.0
#
#    Lean Meat & Alternatives  Dairy (Reduced Fat) Additional Serves Range
# 0                       3.0                  2.5                     0-3
# 1                       2.5                  2.5                   0-2.5
# 2                       2.5                  3.5                   0-2.5
# 3                       2.5                  2.5                   0-2.5
# 4                       2.0                  4.0                   0-2.5
# 5                       2.0                  4.0                     0-2
# 6                       3.5                  2.5                   0-2.5
# 7                       2.5                  2.5                   0-2.5

# %% [markdown]
# ### Categorising sale items into the australian reccomended food groups

# %%
import gensim.downloader as api
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# glove model
model = api.load('glove-wiki-gigaword-300')

# define non-food categories to ignore
NON_FOOD_CATEGORIES = [
    'Baby', 'Beauty', 'Toiletries', 'Household Cleaning', 
    'Home & Outdoor', 'Stationery & Media', 'Clothing', 'Pet care'
]

# define dietary guideline categories with some additional keywords
dietary_guidelines = {
    'Vegetables & Legumes': ['vegetables', 'vegetable', 'legumes', 'beans', 'peas', 'broccoli', 'carrot', 'salad', 'greens'],
    'Fruit': ['fruit', 'fruits', 'apple', 'banana', 'orange', 'berry', 'grape', 'melon'],
    'Grains (Wholegrain)': ['bread', 'rice', 'pasta', 'noodles', 'cereal', 'oats', 'grain', 'wheat', 'crackers', 'muffin', 'bagel', 'bun', 'roll', 'wrap', 'pita', 'tortilla'],
    'Lean Meat & Alternatives': ['meat', 'beef', 'chicken', 'pork', 'lamb', 'fish', 'salmon', 'tuna', 'eggs', 'pie', 'sausage', 'bacon', 'ham', 'protein'],
    'Dairy (Reduced Fat)': ['milk', 'cheese', 'yoghurt', 'yogurt', 'dairy', 'cream', 'butter'],
    'Discretionary': ['chocolate', 'candy', 'chips', 'biscuits', 'cookies', 'cake', 'icecream', 'soft-drink', 'lollies', 'snack']
}

def get_text_embedding(words):
    """
    convert a list of words into a single vector by averaging
    """
    vectors = []
    for word in words:
        word_clean = word.lower().strip()
        if word_clean in model:
            vectors.append(model[word_clean])
    
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(300)

def classify_product(woolworths_category, product_name):
    """
    combine Woolworths category + product name to classify into dietary guidelines
    """
    # check if this is a non-food category first
    if woolworths_category in NON_FOOD_CATEGORIES:
        return 'Non-Food', 1.0
    
    # combine category and product name into words
    combined_text = f"{woolworths_category} {product_name}"
    
    # tokenize
    words = []
    for word in combined_text.split():
        # remove numbers and short words
        if len(word) > 2 and not word.isdigit():
            words.append(word)
    
    # get embedding for this product
    product_embedding = get_text_embedding(words)
    
    # get embeddings for each dietary category
    best_category = None
    best_score = -1
    
    for category_name, keywords in dietary_guidelines.items():
        category_embedding = get_text_embedding(keywords)
        
        # calculate similarity
        similarity = cosine_similarity(
            product_embedding.reshape(1, -1),
            category_embedding.reshape(1, -1)
        )[0][0]
        
        if similarity > best_score:
            best_score = similarity
            best_category = category_name
    
    return best_category, best_score

# %%
df['dietary_category'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[0],
    axis=1
)

df['dietary_confidence'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[1],
    axis=1
)

# %%
df_food = df[df['dietary_category'] != 'Non-Food']
df_food.to_csv('food_items_classified_manual_inspect.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category           category stock_code  \
# 0       Dairy (Reduced Fat)             Bakery      91895
# 1             Discretionary             Bakery     552336
# 2                     Fruit             Bakery    6030831
# 3       Grains (Wholegrain)             Bakery     328164
# 4  Lean Meat & Alternatives    Breakfast Foods     786273
# 5      Vegetables & Legumes  Biscuits & Snacks     800481
#
#                                          name  sale_price  original_price  \
# 0               Woolworths Large Pavlova Base         7.5             7.5
# 1  Woolworths Decorated Gingerbread House 70g         3.5             3.5
# 2     Woolworths Luscious Berry Trifle 1.2 kg        25.0            25.0
# 3         Gold Roasted Almond Shortbread 500g        19.0            19.0
# 4         Carman’s Protein Bars 150-200g Pk 5         5.5             7.9
# 5      Maretti Bruschette Roasted Garlic 150g         3.0             3.0
#
#    savings  dietary_confidence
# 0      0.0            0.335953
# 1      0.0            0.385280
# 2      0.0            0.463502
# 3      0.0            0.625547
# 4      2.4            0.588123
# 5      0.0            0.737200

# %%
test = df_food.groupby('dietary_category').first().reset_index()

# %% [markdown]
# ### Extracting key ingredient

# %%
import anthropic
import time
import os
from dotenv import load_dotenv

load_dotenv() 
client = anthropic.Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY")
)

def extract_key_ingredient_claude(product_name):
    """
    use claude to extract the main ingredient from a product name
    """
    try:
        message = client.messages.create(
            model="claude-3-5-haiku-20241022", 
            max_tokens=20,
            messages=[{
                "role": "user",
                "content": f"""Extract ONLY the main food ingredient from this product name. This ingredient is what best describes the item.  
Return just one to three words in singular form, lowercase, no punctuation.

Examples:
- "Woolworths Free Range Eggs 700g Pk 12" → egg
- "Always Fresh Sicilian Olives Pitted 230g" → olive
- "Four'N Twenty Angus Pies 700g" → beef pie
- "Mr Whisk Vanilla Meringues 130g" → meringue
- "Golden Crumpet Rounds Pk 6" → crumpet
- "Philadelphia Original Cream Cheese Twin Block 500g" → cream cheese 
- "Farmers Union Greek Yogurt Pots 150g" → greek yogurt

Product: {product_name}

Main ingredient:"""
            }]
        )
        
        return message.content[0].text.strip().lower()
    
    except Exception as e:
        print(f"Error processing '{product_name}': {e}")
        return 'Unknown'

results = []
for idx, product_name in enumerate(df_food['name'], 1):
    ingredient = extract_key_ingredient_claude(product_name)
    results.append(ingredient)

df_food['key_ingredient'] = results
# Out:
# C:\Users\ciaod\AppData\Local\Temp\ipykernel_10356\1096676492.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['key_ingredient'] = results

# %%
df_food.to_csv('base_table_food.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category           category stock_code  \
# 0       Dairy (Reduced Fat)             Bakery      91895
# 1             Discretionary             Bakery     552336
# 2                     Fruit             Bakery    6030831
# 3       Grains (Wholegrain)             Bakery     328164
# 4  Lean Meat & Alternatives    Breakfast Foods     786273
# 5      Vegetables & Legumes  Biscuits & Snacks     800481
#
#                                          name  sale_price  original_price  \
# 0               Woolworths Large Pavlova Base         7.5             7.5
# 1  Woolworths Decorated Gingerbread House 70g         3.5             3.5
# 2     Woolworths Luscious Berry Trifle 1.2 kg        25.0            25.0
# 3         Gold Roasted Almond Shortbread 500g        19.0            19.0
# 4         Carman’s Protein Bars 150-200g Pk 5         5.5             7.9
# 5      Maretti Bruschette Roasted Garlic 150g         3.0             3.0
#
#    savings  dietary_confidence key_ingredient
# 0      0.0            0.335953        pavlova
# 1      0.0            0.385280    gingerbread
# 2      0.0            0.463502   berry trifle
# 3      0.0            0.625547         almond
# 4      2.4            0.588123    protein bar
# 5      0.0            0.737200     bruschette

# %% [markdown]
# ### Recipes

# %%
load_dotenv()
API_KEY = os.getenv("SPOONACULAR_API_KEY", "")

BASE_URL = "https://api.spoonacular.com"

# %%
COOKING_CATEGORIES = [
    'Baking', 'Canned & Packet food', 'Condiments',
    'Cooking, Seasoning & Gravy', 'Dairy', 'Deli & Chilled',
    'Fruit & Vegetables', 'International Foods', 'Jams & Spreads',
    'Meat', 'Seafood'
]

df_cooking = df_food[df_food['category'].isin(COOKING_CATEGORIES)]

# %%
ingredients = df_cooking['key_ingredient'].unique()
ingredient_string = ','.join(ingredients)

# api call
response = requests.get(
    f"{BASE_URL}/recipes/findByIngredients",
    params={
        'apiKey': API_KEY,
        'ingredients': ingredient_string,
        'number': 50,
        'ranking': 2
    }
)

# %%
if response.status_code == 200:
    recipes = response.json()
    
    sale_ingredients_list = df_cooking['key_ingredient'].unique()
    
    recipe_data = []
    for recipe in recipes:
        recipe_ingredients = [ing['name'] for ing in recipe['usedIngredients']] + \
                            [ing['name'] for ing in recipe['missedIngredients']]
        
        matched_ingredients = set()
        
        for recipe_ing in recipe_ingredients:
            for sale_ing in sale_ingredients_list:
                if sale_ing in recipe_ing.lower() or recipe_ing.lower() in sale_ing:
                    matched_ingredients.add(sale_ing)
        
        product_names = []
        total_savings = 0
        
        for matched_ing in matched_ingredients:
            product = df_cooking[df_cooking['key_ingredient'] == matched_ing].iloc[0]
            
            product_names.append(product['name'])
            total_savings += product['savings']
        
        recipe_data.append({
            'recipe_id': recipe['id'],
            'recipe_name': recipe['title'],
            'no_sale_items': len(matched_ingredients),
            'sale_items': list(matched_ingredients),
            'sale_product_names': product_names,
            'total_savings': round(total_savings, 2),
            'all_ingredients': recipe_ingredients
        })
    
    df_recipes = pd.DataFrame(recipe_data)
    df_recipes = df_recipes.sort_values('no_sale_items', ascending=False)

# %%
df_recipes
# Out:
#     recipe_id                                        recipe_name  \
# 9      652359                               Monte Carlo Sandwich
# 1      633741                                  Baked Potato Soup
# 31     633133                         Avocado Chicken Parmigiana
# 24     157426                  Stuffed Shells with Beef and Broc
# 11     654935                Pasta with Peas and Italian Sausage
# 6      651707                           Mexican Stuffed Potatoes
# 14     655424                                    Pear Dutch Baby
# 27     640509               Cream Cheese Stuffed Chicken Breasts
# 8      647417                         Hot Cheesy Bacon Party Dip
# 10     910030                        Bacon Scallion Deviled Eggs
# 21     716430  Roasted Cabbage Wedge Salad with Yogurt Gorgon...
# 38     157961                                         Kale Rolls
# 32     663553             Tomato and Bacon Pizza With Rice Crust
# 26     637658           Cheesy Ham and Shrimp Macaroni Au Gratin
# 7      639900                                          Colcannon
# 16     648749                                         Kare Katsu
# 3      655601          Penne with Sausage, Tomatoes and Potatoes
# 15     648303                                 Itty Bitty Burgers
# 46     638190                 Chicken Medallions And Fruit Salad
# 47     638453         Chicken with Sun Dried Tomatoes and Olives
# 39     640676         Creamy Polenta with Egg, Arrabiata & Bacon
# 40     633132                              Avocado Chicken Salad
# 36     649229                                           Lamb Pie
# 37     642695                               Feta Stuffed Burgers
# 12     639320                               Chorizo and egg bake
# 25     634703  Beef Tenderloin With Creamy Alouette® Mushroom...
# 30     632778  Artisan Farfalle Pasta With Smoked Salmon and ...
# 41     631738          Chicken with Grape Tomatoes and Mushrooms
# 34     634658                         Beef rolls with vegetables
# 20     637670                              Cheesy Pasta in a Pot
# 5      716370                         Semi Ripe Plantain Pottage
# 0      633594  Baked Eggs and Bacon Cream In Spinach Fettucci...
# 2      650127  Linguine in Cream Sauce with Poached Eggs and ...
# 4      645348                                   Greek Side Salad
# 17    1697687            Spinach Mushroom Omelette with Parmesan
# 13     646368                            Hawaiian Grilled Cheese
# 43     645647                       Grilled Chicken Hunter Style
# 35     632463                          Apple and Potato Fritatta
# 28     775621                  Gorgonzola & Grilled Peach Burger
# 22     639632                                       Classic Ragu
# 45     639337             Chorizo, Bacon, Mushroom and Pea Pasta
# 18     656834  Pork Tenderloin Stuffed With Cranberries and Brie
# 48     668492                      Creamy zucchini and ham pasta
# 49    1747687          Chorizo Parmesan Brussels Sprouts Skillet
# 23     633267                           Bacon and Arugula Quiche
# 33     632297                                        Amatriciana
# 29     659988    Shrimp pasta with white wine tomato cream sauce
[Gold Glaze & Bake Davidson Plum & Honey Ham 8...          17.00
#
#                                       all_ingredients
# 9   [butter, cheese, ham, eggs, milk, turkey, sand...
# 1   [slc bacon, baking potatoes, butter, cheddar c...
# 31  [chicken breast fillet, egg, tomato pasta sauc...
# 24  [cream cheese, ground beef, onion, pasta shell...
# 11  [butter, canned tomatoes, farfalle pasta, saus...
# 6   [extra beef, salsa, yukon gold potatoes, chedd...
# 14  [milk, eggs, butter, pork link sausage, usa bo...
# 27  [bacon, to 3 butter, cream cheese, onion, chic...
# 8   [bacon, cream cheese, mayo, cheddar cheese), r...
# 10  [hardboiled eggs, bacon, mayonnaise, greek yog...
# 21  [bacon, gorgonzola, grape tomatoes, cabbage, g...
# 38  [tomato sauce, canned tomatoes, ground beef, o...
# 32  [rice, egg, mozzarella cheese, tomatoes, at le...
# 26  [elbow pasta, ham, big shitake mushrooms, parm...
# 7   [optional: 2 rashers bacon, butter, cabbage, s...
# 16  [carrot, onions, pork cutlets, potatoes, rice,...
# 3   [butter, canned tomatoes, sausages, penne past...
# 15  [grape tomatoes, hamburger buns, ground beef, ...
# 46  [chicken breast, onion, tomato, some pineapple...
# 47  [juice of lemon, olives and/or kalamata olives...
# 39  [bacon, cream cheese, eggs, goat cheese, parsl...
# 40  [cherry tomatoes, mayonnaise, salad, chicken b...
# 36  [carrot, lamb, onion, potato, shortcrust pastr...
# 37  [feta cheese, hamburger buns, ground beef, oni...
# 12  [cheddar cheese, chorizo sausage, eggs, onion,...
# 25  [beef tenderloin steaks, butter, milk, shallot...
# 30  [5%% cooking cream, artisan pasta, shallots, s...
# 41  [chicken breast halves, mushrooms, grape tomat...
# 34  [bacon, beef steaks, carrot, onion, tomatoes, ...
# 20  [ground beef, onions, spaghetti sauce, canned ...
# 5   [cooking spoon of scent leaves, crayfish powde...
# 0   [bacon, butter, parmigiano-reggiano, heavy cre...
# 2   [bacon, eggs, linguine, milk, onion, whipping ...
# 4   [cucumber, greek feta, kalamata olives, onion,...
# 17  [mushrooms, shallot, parmesan cheese, eggs, bu...
# 13  [pineapple, butter, jalapeno, deli ham, sharp ...
# 43  [chicken breasts, mamma lombardi's marinara sa...
# 35  [carrots, eggs, extra sharp cheddar cheese, on...
# 28  [burger buns, so of gorgonzola cheese, ground ...
# 22  [canned tomatoes, carrot, tagliatelle, ground ...
# 45  [bacon, chorizo links, mushrooms, pasta, garli...
# 18  [pork tenderloin, cranberries, brie cheese, di...
# 48  [double cream, ham, mascarpone, pasta, garlic,...
# 49  [onion, tomatoes, chorizo, parmesan cheese, br...
# 23  [bacon, eggs, heavy cream, pre-baked pastry cr...
# 33  [bucatini, cured pig's cheek, onion, parmesan ...
# 29  [cherry tomatoes, heavy cream, .4 oz. linguine...
# 19                    [bacon, feta cheese, asparagus]
# 44  [bay leaf, canned tomatoes, approximately oxta...
# 42  [marinated feta, parma ham, peach juice, mescl...

# %%
def get_recipe_info(recipe_id):
    endpoint = f"{BASE_URL}/recipes/{recipe_id}/information"
    params = {'apiKey': API_KEY}
    response = requests.get(endpoint, params=params)
    if response.status_code == 200:
        return response.json()
    return None

recipe_instructions = []

for recipe_id in df_recipes['recipe_id']:
    recipe_info = get_recipe_info(recipe_id)
    
    if recipe_info:
        recipe_instructions.append({
            'recipe_id': recipe_id,
            'instructions': recipe_info.get('instructions', 'No instructions available'),
            'cooking_time': recipe_info.get('readyInMinutes', None),
            'servings': recipe_info.get('servings', None),
            'source_url': recipe_info.get('sourceUrl', None)
        })
    
    time.sleep(0.5)

df_instructions = pd.DataFrame(recipe_instructions)

df_recipes_full = df_recipes.merge(df_instructions, on='recipe_id', how='left')

# %%
df_recipes_full
# Out:
#     recipe_id                                        recipe_name  \
# 0      652359                               Monte Carlo Sandwich
# 1      633741                                  Baked Potato Soup
# 2      633133                         Avocado Chicken Parmigiana
# 3      157426                  Stuffed Shells with Beef and Broc
# 4      654935                Pasta with Peas and Italian Sausage
# 5      651707                           Mexican Stuffed Potatoes
# 6      655424                                    Pear Dutch Baby
# 7      640509               Cream Cheese Stuffed Chicken Breasts
# 8      647417                         Hot Cheesy Bacon Party Dip
# 9      910030                        Bacon Scallion Deviled Eggs
# 10     716430  Roasted Cabbage Wedge Salad with Yogurt Gorgon...
# 11     157961                                         Kale Rolls
# 12     663553             Tomato and Bacon Pizza With Rice Crust
# 13     637658           Cheesy Ham and Shrimp Macaroni Au Gratin
# 14     639900                                          Colcannon
# 15     648749                                         Kare Katsu
# 16     655601          Penne with Sausage, Tomatoes and Potatoes
# 17     648303                                 Itty Bitty Burgers
# 18     638190                 Chicken Medallions And Fruit Salad
# 19     638453         Chicken with Sun Dried Tomatoes and Olives
# 20     640676         Creamy Polenta with Egg, Arrabiata & Bacon
# 21     633132                              Avocado Chicken Salad
# 22     649229                                           Lamb Pie
# 23     642695                               Feta Stuffed Burgers
# 24     639320                               Chorizo and egg bake
# 25     634703  Beef Tenderloin With Creamy Alouette® Mushroom...
# 26     632778  Artisan Farfalle Pasta With Smoked Salmon and ...
# 27     631738          Chicken with Grape Tomatoes and Mushrooms
# 28     634658                         Beef rolls with vegetables
# 29     637670                              Cheesy Pasta in a Pot
# 30     716370                         Semi Ripe Plantain Pottage
# 31     633594  Baked Eggs and Bacon Cream In Spinach Fettucci...
# 32     650127  Linguine in Cream Sauce with Poached Eggs and ...
# 33     645348                                   Greek Side Salad
# 34    1697687            Spinach Mushroom Omelette with Parmesan
# 35     646368                            Hawaiian Grilled Cheese
# 36     645647                       Grilled Chicken Hunter Style
# 37     632463                          Apple and Potato Fritatta
# 38     775621                  Gorgonzola & Grilled Peach Burger
# 39     639632                                       Classic Ragu
# 40     639337             Chorizo, Bacon, Mushroom and Pea Pasta
# 41     656834  Pork Tenderloin Stuffed With Cranberries and Brie
# 42     668492                      Creamy zucchini and ham pasta
# 43    1747687          Chorizo Parmesan Brussels Sprouts Skillet
# 44     633267                           Bacon and Arugula Quiche
# 45     632297                                        Amatriciana
# 46     659988    Shrimp pasta with white wine tomato cream sauce
# 47     658491       Roasted Asparagus With Bacon and Feta Cheese
# 48     658126                             Red Wine Stewed Oxtail
# 49     655174  Peach, Ham and Feta Salad with Fruity Olive Oi...
#
#     no_sale_items                                         sale_items  \
# 0              15  [ham, fetta cheese, egg, peanut butter, blue c...
# 1              10  [potato, sour cream, peanut butter, onion, but...
# 2              10  [egg, chicken, pasta sauce, cheese, pasta, sau...
# 3              10  [tomato, tomato sauce, onion, carrot broccoli ...
# 4               9  [peanut butter, butter, pasta, pork sausage, s...
# 5               9  [potato, sour cream, salsa, onion, cheese, cre...
# 6               8  [egg, peanut butter, pork, butter, pear, sausa...
# 7               8  [onion, chicken, butter, cream, bacon, cheese,...
# 8               8  [tomato, onion, cream, meat, mayonnaise, bacon...
# 9               7  [egg, oil, yogurt, greek yogurt, mayonnaise, b...
# 10              7  [lemon, yogurt, greek yogurt, grape, bacon, to...
# 11              7  [onion, kale slaw, rice, beef, tomato, sauce, ...
# 12              7  [egg, tomato, turkey, egg nog, rice, bacon, ch...
# 13              7  [ham, carrot broccoli cauliflower, pasta, mush...
# 14              7  [potato, peanut butter, onion, butter, milk, b...
# 15              7  [potato, pork, onion, carrot broccoli cauliflo...
# 16              6  [potato, peanut butter, butter, pasta, sausage...
# 17              6        [ham, cheese, mustard, grape, beef, tomato]
# 18              6  [pineapple, onion, chicken, tomato, chicken br...
# 19              6  [chicken, lemon, kalamata olive, olive, tomato...
# 20              6  [egg, cream, goat cheese, bacon, cheese, cream...
# 21              6  [chicken, salad, mayonnaise, cherry, tomato, c...
# 22              6  [lamb, potato, onion, carrot broccoli cauliflo...
# 23              6    [ham, tomato, onion, feta cheese, beef, cheese]
# 24              6  [egg, onion, chilli pepper, sausage, chilli, c...
# 25              6  [peanut butter, butter, mushroom, vegetable, m...
# 26              6  [chicken, salmon, pasta, cream, salmon pate, t...
# 27              6  [onion, chicken, mushroom, grape, tomato, chic...
# 28              6  [onion, carrot broccoli cauliflower, carrot, b...
# 29              6      [onion, pasta, mushroom, beef, tomato, sauce]
# 30              5     [onion, fish, vegetable, tomato, tomato sauce]
# 31              5         [egg, peanut butter, butter, cream, bacon]
# 32              5                   [egg, onion, cream, milk, bacon]
# 33              5   [onion, cucumber, kalamata olive, olive, tomato]
# 34              5     [egg, peanut butter, butter, mushroom, cheese]
# 35              5    [ham, peanut butter, cheese, butter, pineapple]
# 36              5  [chicken, sauce, mushroom, cheese, chicken bre...
# 37              5               [potato, egg, onion, carrot, cheese]
# 38              5                  [onion, peach, beef, cheese, pea]
# 39              5  [onion, carrot broccoli cauliflower, sausage, ...
# 40              5         [pasta sauce, pasta, mushroom, bacon, pea]
# 41              4                      [brie, cheese, pork, mustard]
# 42              4                   [ham, cream, pasta, pasta sauce]
# 43              4             [prawn chorizo, tomato, onion, cheese]
# 44              4                        [bacon, cream, egg, cheese]
# 45              4                     [chili, cheese, tomato, onion]
# 46              3                            [cherry, cream, tomato]
# 47              3                       [bacon, feta cheese, cheese]
# 48              3                              [leaf, tomato, onion]
# 49              3                                  [ham, peach, pea]
#
#                                    sale_product_names  total_savings  \
# 0   [Gold Glaze & Bake Davidson Plum & Honey Ham 8...          16.10
# 1   [Woolworths Deli Style Potato Chips 175g, Bull...          12.55
# 2   [Praise Whole Egg Mayonnaise or Garlic Aioli 4...
# 4   [butter, canned tomatoes, farfalle pasta, saus...
# 5   [extra beef, salsa, yukon gold potatoes, chedd...
# 6   [milk, eggs, butter, pork link sausage, usa bo...
# 7   [bacon, to 3 butter, cream cheese, onion, chic...
# 8   [bacon, cream cheese, mayo, cheddar cheese), r...
# 9   [hardboiled eggs, bacon, mayonnaise, greek yog...
# 10  [bacon, gorgonzola, grape tomatoes, cabbage, g...
# 11  [tomato sauce, canned tomatoes, ground beef, o...
# 12  [rice, egg, mozzarella cheese, tomatoes, at le...
# 13  [elbow pasta, ham, big shitake mushrooms, parm...
# 14  [optional: 2 rashers bacon, butter, cabbage, s...
# 15  [carrot, onions, pork cutlets, potatoes, rice,...
# 16  [butter, canned tomatoes, sausages, penne past...
# 17  [grape tomatoes, hamburger buns, ground beef, ...
# 18  [chicken breast, onion, tomato, some pineapple...
# 19  [juice of lemon, olives and/or kalamata olives...
# 20  [bacon, cream cheese, eggs, goat cheese, parsl...
# 21  [cherry tomatoes, mayonnaise, salad, chicken b...
# 22  [carrot, lamb, onion, potato, shortcrust pastr...
# 23  [feta cheese, hamburger buns, ground beef, oni...
# 24  [cheddar cheese, chorizo sausage, eggs, onion,...
# 25  [beef tenderloin steaks, butter, milk, shallot...
# 26  [5%% cooking cream, artisan pasta, shallots, s...
# 27  [chicken breast halves, mushrooms, grape tomat...
# 28  [bacon, beef steaks, carrot, onion, tomatoes, ...
# 29  [ground beef, onions, spaghetti sauce, canned ...
# 30  [cooking spoon of scent leaves, crayfish powde...
# 31  [bacon, butter, parmigiano-reggiano, heavy cre...
# 32  [bacon, eggs, linguine, milk, onion, whipping ...
# 33  [cucumber, greek feta, kalamata olives, onion,...
# 34  [mushrooms, shallot, parmesan cheese, eggs, bu...
# 35  [pineapple, butter, jalapeno, deli ham, sharp ...
# 36  [chicken breasts, mamma lombardi's marinara sa...
# 37  [carrots, eggs, extra sharp cheddar cheese, on...
# 38  [burger buns, so of gorgonzola cheese, ground ...
# 39  [canned tomatoes, carrot, tagliatelle, ground ...
# 40  [bacon, chorizo links, mushrooms, pasta, garli...
# 41  [pork tenderloin, cranberries, brie cheese, di...
# 42  [double cream, ham, mascarpone, pasta, garlic,...
# 43  [onion, tomatoes, chorizo, parmesan cheese, br...
# 44  [bacon, eggs, heavy cream, pre-baked pastry cr...
# 45  [bucatini, cured pig's cheek, onion, parmesan ...
# 46  [cherry tomatoes, heavy cream, .4 oz. linguine...
# 47                    [bacon, feta cheese, asparagus]
# 48  [bay leaf, canned tomatoes, approximately oxta...
# 49  [marinated feta, parma ham, peach juice, mescl...
#
#                                          instructions  cooking_time  servings  \
# 0   <ol><li>Spread butter on each slice of bread. ...          45.0       9.0
# 1   <ol><li>Bake the potatoes until done. Let cool...          45.0       1.0
# 2   Preheat oven to 200C/400F fan-forced. Place ch...          45.0       8.0
# 3   <p>1. Steam your frozen broccoli and cut it in...          60.0       2.0
# 4   <ol><li>Cook the pasta following the package d...          45.0       4.0
# 5   Pierce potatoes and microwave the potatoes on ...          45.0       4.0
# 6   Combine flour, milk, eggs and salt; beat until...          45.0       6.0
# 7   <ol><li>Preheat the oven to 350 F.</li><li>In ...          45.0       4.0
# 8   Preheat oven to 350\nMix together cream cheese...          45.0      16.0
# 9   Halve eggs lengthwise and remove yolks. Place ...          45.0      24.0
# 10                                                             45.0       4.0
# 11  <p> Bring a pan of lightly salted water to a b...          90.0       8.0
# 12  <ol><li>Preheat oven to 400F.</li><li>To make ...          45.0       8.0
# 13  <ol><li>Cut off base of broccoli stem. Cut bro...          45.0       4.0
# 14  <ol><li>Cut into top of cabbage and hollow it ...          45.0       8.0
# 15  <ol><li>Cook pork in a pan with oil; set aside...          45.0      12.0
# 16  <ol><li>In a large pot add the potatoes and sa...          45.0       4.0
# 17  <ol><li>Preheat oven to 400 degrees.</li><li>I...          45.0      16.0
# 18  Cut the chicken breast into medallions. Sprink...          45.0      12.0
# 19  Preheat oven to 425.  Combine garlic, lemon ju...          45.0       6.0
# 20  <ol><li>Preheat the oven to 425 degrees F.</li...          45.0       4.0
# 21  <ol><li>Season chicken breast with a little sa...          45.0       2.0
# 22  <ol><li>Use a pan with an airtight lid. Put a ...          45.0       1.0
# 23  <ol><li>Season meat with black pepper.</li><li...          45.0       4.0
# 24  <ol><li>Preheat the oven to 170 C</li><li>In a...          30.0       3.0
# 25  <ol><li>Heat broiler.</li><li>Coat all sides o...          45.0       2.0
# 26  <ol><li>In a large pot of boiling salted water...          45.0       2.0
# 27  Heat 1 tablespoon oil in a 12-inch skillet ove...          45.0       4.0
# 28  <ol><li>Beat the beef steaks lightly, season w...          45.0       2.0
# 29  Preheat oven at 350 degrees.\nCook the ground ...          45.0       8.0
# 30  Peel your plantain, cube and place in a pot. A...          45.0       2.0
# 31  I begin with my bacon (Ive never had bacon thi...          45.0       3.0
# 32  <ol><li>Cut each strip of bacon into halves. P...          25.0       2.0
# 33  <ol><li> Slice the vegetables into bite-size w...          15.0       4.0
# 34  Clean and chop mushrooms, wash and dry spinach...          20.0       2.0
# 35  Heat 2 tbsp of butter in a small pan over medi...          45.0       4.0
# 36  <ol><li>Coat chicken breasts in 1 ounce of ext...          45.0       4.0
# 37  <ol><li>Directions: Preheat oven to 375 degree...          45.0       8.0
# 38                                               None          45.0       4.0
# 39  <ol><li>In a pot add a couple glugs of olive o...         180.0       6.0
# 40  <ol><li>Put the pasta in a pan and then boil t...          45.0       6.0
# 41  Preheat oven to 350. In a small bowl, whisk to...          45.0       2.0
# 42  <ol><li>Read the detailed instructions here: <...          25.0       4.0
# 43  <ol><li>Preheat the oven to 350° F </li><li>In...          45.0       3.0
# 44  <ol><li>Preheat oven to 400 F. Thaw purchased ...          45.0       9.0
# 45  <ol><li>In a pot heat the olive oil, add the c...          45.0       4.0
# 46  <ol><li>If you are using frozen shrimp, remove...          45.0       4.0
# 47  <ol><li>Preheat oven to 500.</li><li>Place the...          45.0       6.0
# 48  <ol><li>In a large stockpot or pressure cooker...          45.0       6.0
# 49                                                NaN           NaN       NaN
#
