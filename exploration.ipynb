# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %% [markdown]
# ### Woolworths weekly catalogue scraper

# %%
# api endpoint to get category list (use "view" endpoint)
url_view = "https://embed.salefinder.com.au/productlist/view/62107/"

# parameters for the request
params = {
    'locationId': '4679',
    'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
    'saleGroup': '0',
    'rows_per_page': '10',
}

# headers to make our request look like a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
    'Accept': '*/*',
}

# fetch the main catalogue page
response = requests.get(url_view, params=params, headers=headers)
json_text = response.text.strip()[1:-1]
data = json.loads(json_text)

print(f"Fetched: {data['saleName']}")
print(f"Valid: {data['startDate']} to {data['endDate']}\n")

# parse the HTML to extract categories
soup = BeautifulSoup(data['content'], 'html.parser')
categories = {}

for link in soup.find_all('a', class_='sf-navcategory-link'):
    href = link.get('href', '')
    if 'categoryId=' in href:
        category_id = href.split('categoryId=')[1].split('&')[0]
        category_name = link.text.strip()
        categories[category_id] = category_name
# Out:
# Fetched: Weekly Catalogue NSW
# Valid: 2025-11-12T00:00:00 to 2025-11-18T23:59:59

# %%
url_category = "https://embed.salefinder.com.au/productlist/category/62107/"

# list to store ALL products from ALL categories
all_products = []

# loop through each category
for category_id, category_name in categories.items():
    print(f"Scraping {category_name}...", end=" ")
    
    # parameters for this specific category
    params = {
        'locationId': '4679',
        'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
        'saleGroup': '0',
        'categoryId': category_id, 
        'rows_per_page': '500',
    }
    
    # api request
    response = requests.get(url_category, params=params, headers=headers)
    json_text = response.text.strip()[1:-1]
    data = json.loads(json_text)
    
    # parse
    soup = BeautifulSoup(data['content'], 'html.parser')
    
    # extract products
    for product in soup.find_all('div', class_='shelfProductStamp'):
        name_tag = product.find('span', class_='sf-item-heading')
        sale_price_tag = product.find('span', class_='sf-pricedisplay')
        savings_tag = product.find('span', class_='sf-regprice')
        
        if not name_tag or not sale_price_tag:
            continue
        
        name = name_tag.text.strip()
        sale_price = sale_price_tag.text.strip()
        stock_code = product.get('data-stockcode')
        
        sale_value = float(sale_price.replace('$', ''))
        
        if savings_tag:
            savings = savings_tag.text.strip()
            savings_value = float(savings.replace('$', ''))
            original_value = sale_value + savings_value
        else:
            savings_value = 0.0
            original_value = sale_value
        
        all_products.append({
            'category': category_name,
            'stock_code': stock_code,
            'name': name,
            'sale_price': sale_value,
            'original_price': original_value,
            'savings': savings_value
        })
    
    print(f"{len([p for p in all_products if p['category'] == category_name])} products")
    time.sleep(0.3) 

# Create DataFrame
df = pd.DataFrame(all_products)
# Out:
# Scraping Baby... 5 products
# Scraping Bakery... 30 products
# Scraping Baking... 2 products
# Scraping Beauty... 13 products
# Scraping Biscuits & Snacks... 19 products
# Scraping Breakfast Foods... 10 products
# Scraping Canned & Packet food... 22 products
# Scraping Condiments... 4 products
# Scraping Confectionery... 22 products
# Scraping Cooking, Seasoning & Gravy... 3 products
# Scraping Dairy... 19 products
# Scraping Deli & Chilled... 21 products
# Scraping Desserts... 3 products
# Scraping Drinks... 27 products
# Scraping Frozen Food... 36 products
# Scraping Fruit & Vegetables... 13 products
# Scraping Health & Wellbeing... 9 products
# Scraping Health Foods... 6 products
# Scraping Home & Outdoor... 49 products
# Scraping Household Cleaning... 10 products
# Scraping International Foods... 2 products
# Scraping Jams & Spreads... 1 products
# Scraping Meat... 25 products
# Scraping Papergoods, Wraps & Bags... 2 products
# Scraping Pet care... 9 products
# Scraping Seafood... 5 products
# Scraping Stationery & Media... 12 products
# Scraping Toiletries... 14 products

# %%
df = pd.DataFrame(all_products)

df.groupby('category').first().reset_index()
# Out:
#                       category stock_code  \
# 0                         Baby     200703
# 1                       Bakery      49622
# 2                       Baking     205222
# 3                       Beauty     225912
# 4            Biscuits & Snacks     479848
# 5              Breakfast Foods      49622
# 6         Canned & Packet food     259537
# 7                   Condiments     323081
# 8                Confectionery     814558
# 9   Cooking, Seasoning & Gravy    6049885
# 10                       Dairy     686461
# 11              Deli & Chilled     686461
# 12                    Desserts     690034
# 13                      Drinks      32731
# 14                 Frozen Food     485660
# 15          Fruit & Vegetables      85794
# 16          Health & Wellbeing     230860
# 17                Health Foods     104528
# 18              Home & Outdoor    6017746
# 19          Household Cleaning     468551
# 20         International Foods     251433
# 21              Jams & Spreads      72546
# 22                        Meat     713425
# 23    Papergoods, Wraps & Bags     679037
# 24                    Pet care    6039182
# 25                     Seafood     157052
# 26          Stationery & Media     693103
# 27                  Toiletries     225912
#
#                                                  name  sale_price  \
# 0                  Huggies Ultra Dry Nappies Pk 30-54       13.00
# 1                          Golden Crumpet Rounds Pk 6        2.40
# 2               Woolworths Free Range Eggs 700g Pk 12        6.50
# 3              Dove Beauty Cream Bar Original 2 x 90g        2.75
# 4                           Pringles Potato Chips 53g        1.35
# 5                          Golden Crumpet Rounds Pk 6        2.40
# 6   Ho Mai Spring Roll or Entertainer Pack 1 kg Pk...        8.00
# 7                  Yumi’s Dips 200g – From the Fridge        3.50
# 8   Cadbury Dairy Milk, Bubbly or Marvellous Creat...        4.00
# 9                                    Maggi Gravy 1 kg       12.50
# 10  Farmers Union Greek Yogurt Pouches 130g – From...        1.25
# 11  Farmers Union Greek Yogurt Pouches 130g – From...        1.25
# 12                    Woolworths Petite Pavlovas Pk 9        6.50
# 13  Coca-Cola Classic, Zero Sugar or Diet Soft Dri...        2.00
# 14    Streets Magnum or Magnum Minis 360-428ml Pk 4-6        6.00
# 15           Australian Snackables™ Carrots 250g Pack        3.00
# 16  TENA Incontinence Pads Mini Plus Long Length P...        4.85
# 17  Vege Chips, Nibbles or Straws 75g – From the H...        2.95
# 18                          Christmas Wreath Assorted       22.00
# 19          OMO Laundry Liquid 2 Litre or Powder 2 kg       15.00
# 20                  Old El Paso Premium Kits 295-505g        4.50
# 21  Philadelphia Original Cream Cheese Twin Block ...        9.00
# 22   D’Orsogna Tasty Sticks Mild 400g – From the Deli       10.00
# 23           Kleenex Complete Clean Toilet Paper Pk 9        4.50
# 24                  Churu Puree Cat Treats Pk 4 x 14g        2.25
# 25  Woolworths Australian Fresh Salmon Portions Sk...       13.00
# 26  Energizer Max Plus High Performance Alkaline B...       16.10
# 27             Dove Beauty Cream Bar Original 2 x 90g        2.75
#
#     original_price  savings
# 0             22.0     9.00
# 1              4.8     2.40
# 2             13.1     6.60
# 3              5.5     2.75
# 4              2.7     1.35
# 5              4.8     2.40
# 6             10.0     2.00
# 7              4.5     1.00
# 8              8.0     4.00
# 9             12.5     0.00
# 10             2.5     1.25
# 11             2.5     1.25
# 12             6.5     0.00
# 13             4.0     2.00
# 14            12.0     6.00
# 15             7.0     4.00
# 16             7.0     2.15
# 17             5.9     2.95
# 18            22.0     0.00
# 19            30.0    15.00
# 20             9.5     5.00
# 21            19.0    10.00
# 22            12.5     2.50
# 23             9.0     4.50
# 24             4.5     2.25
# 25            15.0     2.00
# 26            32.2    16.10
# 27             5.5     2.75

# %%
df['category'].unique()
# Out:
# array(['Baby', 'Bakery', 'Baking', 'Beauty', 'Biscuits & Snacks',
#        'Breakfast Foods', 'Canned & Packet food', 'Condiments',
#        'Confectionery', 'Cooking, Seasoning & Gravy', 'Dairy',
#        'Deli & Chilled', 'Desserts', 'Drinks', 'Frozen Food',
#        'Fruit & Vegetables', 'Health & Wellbeing', 'Health Foods',
#        'Home & Outdoor', 'Household Cleaning', 'International Foods',
#        'Jams & Spreads', 'Meat', 'Papergoods, Wraps & Bags', 'Pet care',
#        'Seafood', 'Stationery & Media', 'Toiletries'], dtype=object)

# %% [markdown]
# ### Australia food guidelines

# %% [markdown]
# https://www.eatforhealth.gov.au/food-essentials/how-much-do-we-need-each-day/recommended-number-serves-adults

# %%
# converting the table above into a df
dietary_guidelines = {
    'Group': [
        'Men 19-50',
        'Men 51-70', 
        'Men 70+',
        'Women 19-50',
        'Women 51-70',
        'Women 70+',
        'Pregnant',
        'Lactating'
    ],
    'Vegetables & Legumes': [6, 5.5, 5, 5, 5, 5, 5, 7.5],
    'Fruit': [2, 2, 2, 2, 2, 2, 2, 2],
    'Grains (Wholegrain)': [6, 6, 4.5, 6, 4, 3, 8.5, 9],
    'Lean Meat & Alternatives': [3, 2.5, 2.5, 2.5, 2, 2, 3.5, 2.5],
    'Dairy (Reduced Fat)': [2.5, 2.5, 3.5, 2.5, 4, 4, 2.5, 2.5],
    'Additional Serves Range': ['0-3', '0-2.5', '0-2.5', '0-2.5', '0-2.5', '0-2', '0-2.5', '0-2.5']
}

df_guidelines = pd.DataFrame(dietary_guidelines)

df_guidelines
# Out:
#          Group  Vegetables & Legumes  Fruit  Grains (Wholegrain)  \
# 0    Men 19-50                   6.0      2                  6.0
# 1    Men 51-70                   5.5      2                  6.0
# 2      Men 70+                   5.0      2                  4.5
# 3  Women 19-50                   5.0      2                  6.0
# 4  Women 51-70                   5.0      2                  4.0
# 5    Women 70+                   5.0      2                  3.0
# 6     Pregnant                   5.0      2                  8.5
# 7    Lactating                   7.5      2                  9.0
#
#    Lean Meat & Alternatives  Dairy (Reduced Fat) Additional Serves Range
# 0                       3.0                  2.5                     0-3
# 1                       2.5                  2.5                   0-2.5
# 2                       2.5                  3.5                   0-2.5
# 3                       2.5                  2.5                   0-2.5
# 4                       2.0                  4.0                   0-2.5
# 5                       2.0                  4.0                     0-2
# 6                       3.5                  2.5                   0-2.5
# 7                       2.5                  2.5                   0-2.5

# %% [markdown]
# ### Categorising sale items into the australian reccomended food groups

# %%
import gensim.downloader as api
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# glove model
model = api.load('glove-wiki-gigaword-300')

# define non-food categories to ignore
NON_FOOD_CATEGORIES = [
    'Baby', 'Beauty', 'Toiletries', 'Household Cleaning', 
    'Home & Outdoor', 'Stationery & Media', 'Clothing', 'Pet care'
]

# define dietary guideline categories with some additional keywords
dietary_guidelines = {
    'Vegetables & Legumes': ['vegetables', 'vegetable', 'legumes', 'beans', 'peas', 'broccoli', 'carrot', 'salad', 'greens'],
    'Fruit': ['fruit', 'fruits', 'apple', 'banana', 'orange', 'berry', 'grape', 'melon'],
    'Grains (Wholegrain)': ['bread', 'rice', 'pasta', 'noodles', 'cereal', 'oats', 'grain', 'wheat', 'crackers', 'muffin', 'bagel', 'bun', 'roll', 'wrap', 'pita', 'tortilla'],
    'Lean Meat & Alternatives': ['meat', 'beef', 'chicken', 'pork', 'lamb', 'fish', 'salmon', 'tuna', 'eggs', 'pie', 'sausage', 'bacon', 'ham', 'protein'],
    'Dairy (Reduced Fat)': ['milk', 'cheese', 'yoghurt', 'yogurt', 'dairy', 'cream', 'butter'],
    'Discretionary': ['chocolate', 'candy', 'chips', 'biscuits', 'cookies', 'cake', 'icecream', 'soft-drink', 'lollies', 'snack']
}

def get_text_embedding(words):
    """
    convert a list of words into a single vector by averaging
    """
    vectors = []
    for word in words:
        word_clean = word.lower().strip()
        if word_clean in model:
            vectors.append(model[word_clean])
    
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(300)

def classify_product(woolworths_category, product_name):
    """
    combine Woolworths category + product name to classify into dietary guidelines
    """
    # check if this is a non-food category first
    if woolworths_category in NON_FOOD_CATEGORIES:
        return 'Non-Food', 1.0
    
    # combine category and product name into words
    combined_text = f"{woolworths_category} {product_name}"
    
    # tokenize
    words = []
    for word in combined_text.split():
        # remove numbers and short words
        if len(word) > 2 and not word.isdigit():
            words.append(word)
    
    # get embedding for this product
    product_embedding = get_text_embedding(words)
    
    # get embeddings for each dietary category
    best_category = None
    best_score = -1
    
    for category_name, keywords in dietary_guidelines.items():
        category_embedding = get_text_embedding(keywords)
        
        # calculate similarity
        similarity = cosine_similarity(
            product_embedding.reshape(1, -1),
            category_embedding.reshape(1, -1)
        )[0][0]
        
        if similarity > best_score:
            best_score = similarity
            best_category = category_name
    
    return best_category, best_score

# %%
df['dietary_category'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[0],
    axis=1
)

df['dietary_confidence'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[1],
    axis=1
)

# %%
df_food = df[df['dietary_category'] != 'Non-Food']
df_food.to_csv('food_items_classified_manual_inspect.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category    category stock_code  \
# 0       Dairy (Reduced Fat)      Bakery    6040676
# 1             Discretionary      Bakery     157944
# 2                     Fruit      Bakery     904886
# 3       Grains (Wholegrain)      Bakery      49622
# 4  Lean Meat & Alternatives      Baking     205222
# 5      Vegetables & Legumes  Condiments     465039
#
#                                                 name  sale_price  \
# 0                    Mr Whisk Vanilla Meringues 130g         6.5
# 1               Woolworths Petite Vol Au Vents Pk 12         4.5
# 2  Walker's Cranberry & Clementine Fruit Mince Pi...         6.5
# 3                         Golden Crumpet Rounds Pk 6         2.4
# 4              Woolworths Free Range Eggs 700g Pk 12         6.5
# 5           Always Fresh Sicilian Olives Pitted 230g         3.3
#
#    original_price  savings  dietary_confidence
# 0             6.5      0.0            0.653899
# 1             4.5      0.0            0.269072
# 2             6.5      0.0            0.675821
# 3             4.8      2.4            0.395892
# 4            13.1      6.6            0.513886
# 5             4.8      1.5            0.605417

# %%
test = df_food.groupby('dietary_category').first().reset_index()

# %% [markdown]
# ### Extracting key ingredient

# %%
import anthropic
import time
import os
from dotenv import load_dotenv

load_dotenv() 
client = anthropic.Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY")
)

def extract_key_ingredient_claude(product_name):
    """
    use claude to extract the main ingredient from a product name
    """
    try:
        message = client.messages.create(
            model="claude-3-5-haiku-20241022", 
            max_tokens=20,
            messages=[{
                "role": "user",
                "content": f"""Extract ONLY the main food ingredient from this product name. 
Return just one or two words in singular form, lowercase, no punctuation.

Examples:
- "Woolworths Free Range Eggs 700g Pk 12" → egg
- "Always Fresh Sicilian Olives Pitted 230g" → olive
- "Four'N Twenty Angus Pies 700g" → beef pie
- "Mr Whisk Vanilla Meringues 130g" → meringue
- "Golden Crumpet Rounds Pk 6" → crumpet

Product: {product_name}

Main ingredient:"""
            }]
        )
        
        return message.content[0].text.strip().lower()
    
    except Exception as e:
        print(f"Error processing '{product_name}': {e}")
        return 'Unknown'

results = []
for idx, product_name in enumerate(df_food['name'], 1):
    ingredient = extract_key_ingredient_claude(product_name)
    results.append(ingredient)

df_food['key_ingredient'] = results
# Out:
# C:\Users\ciaod\AppData\Local\Temp\ipykernel_2748\2577631396.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['key_ingredient'] = results

# %%
df_food.to_csv('base_table_food.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category    category stock_code  \
# 0       Dairy (Reduced Fat)      Bakery    6040676
# 1             Discretionary      Bakery     157944
# 2                     Fruit      Bakery     904886
# 3       Grains (Wholegrain)      Bakery      49622
# 4  Lean Meat & Alternatives      Baking     205222
# 5      Vegetables & Legumes  Condiments     465039
#
#                                                 name  sale_price  \
# 0                    Mr Whisk Vanilla Meringues 130g         6.5
# 1               Woolworths Petite Vol Au Vents Pk 12         4.5
# 2  Walker's Cranberry & Clementine Fruit Mince Pi...         6.5
# 3                         Golden Crumpet Rounds Pk 6         2.4
# 4              Woolworths Free Range Eggs 700g Pk 12         6.5
# 5           Always Fresh Sicilian Olives Pitted 230g         3.3
#
#    original_price  savings  dietary_confidence key_ingredient
# 0             6.5      0.0            0.653899       meringue
# 1             4.5      0.0            0.269072         pastry
# 2             6.5      0.0            0.675821          fruit
# 3             4.8      2.4            0.395892        crumpet
# 4            13.1      6.6            0.513886            egg
# 5             4.8      1.5            0.605417          olive

# %% [markdown]
# ### Recipes

# %%
load_dotenv()
API_KEY = os.getenv("SPOONACULAR_API_KEY", "")

BASE_URL = "https://api.spoonacular.com"

# %%
COOKING_CATEGORIES = [
    'Baking', 'Canned & Packet food', 'Condiments',
    'Cooking, Seasoning & Gravy', 'Dairy', 'Deli & Chilled',
    'Fruit & Vegetables', 'International Foods', 'Jams & Spreads',
    'Meat', 'Seafood'
]

df_cooking = df_food[df_food['category'].isin(COOKING_CATEGORIES)]

# %%
# Get unique cooking ingredients
ingredients = df_cooking['key_ingredient'].unique()
ingredient_string = ','.join(ingredients)

response = requests.get(
    f"{BASE_URL}/recipes/findByIngredients",
    params={
        'apiKey': API_KEY,
        'ingredients': ingredient_string,
        'number': 10,
        'ranking': 2  # maximize used ingredients
    }
)

print(f"\nStatus: {response.status_code}")
if response.status_code == 200:
    print(json.dumps(response.json(), indent=2))
# Out:
# Status: 200
# [
#   {
#     "id": 636458,
#     "title": "Bunny Eggs Kids Breakfast",
#     "image": "https://img.spoonacular.com/recipes/636458-312x231.jpg",
#     "imageType": "jpg",
#     "usedIngredientCount": 4,
#     "missedIngredientCount": 0,
#     "missedIngredients": [],
#     "usedIngredients": [
#       {
#         "id": 10123,
#         "amount": 12.0,
#         "unit": "slices",
#         "unitLong": "slices",
#         "unitShort": "slice",
#         "aisle": "Meat",
#         "name": "bacon",
#         "original": "12 slices bacon",
#         "originalName": "bacon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/raw-bacon.png"
#       },
#       {
#         "id": 9050,
#         "amount": 12.0,
#         "unit": "",
#         "unitLong": "",
#         "unitShort": "",
#         "aisle": "Produce",
#         "name": "blueberries",
#         "original": "12 fresh blueberries",
#         "originalName": "fresh blueberries",
#         "meta": [
#           "fresh"
#         ],
#         "extendedName": "fresh blueberries",
#         "image": "https://img.spoonacular.com/ingredients_100x100/blueberries.jpg"
#       },
#       {
#         "id": 1123,
#         "amount": 2.0,
#         "unit": "extra large",
#         "unitLong": "extra larges",
#         "unitShort": "extra large",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "eggs",
#         "original": "2 extra large eggs",
#         "originalName": "eggs",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/egg.png"
#       },
#       {
#         "id": 1051009,
#         "amount": 2.0,
#         "unit": "large slices",
#         "unitLong": "large slices",
#         "unitShort": "large slices",
#         "aisle": "Cheese",
#         "name": "mild cheddar cheese",
#         "original": "2 large slices mild cheddar cheese, cut into thin strips",
#         "originalName": "mild cheddar cheese, cut into thin strips",
#         "meta": [
#           "cut into thin strips"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cheddar-cheese.png"
#       }
#     ],
#     "unusedIngredients": [
#       {
#         "id": 18010,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Baking",
#         "name": "baking mix",
#         "original": "baking mix",
#         "originalName": "baking mix",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10118368,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "spring roll",
#         "original": "spring roll",
#         "originalName": "spring roll",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/rice-paper.jpg"
#       },
#       {
#         "id": 5006,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "whole chicken",
#         "original": "chicken",
#         "originalName": "chicken",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/whole-chicken.jpg"
#       },
#       {
#         "id": 5165,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "turkey",
#         "original": "turkey",
#         "originalName": "turkey",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/turkey-raw-whole.jpg"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "pasta",
#         "original": "pasta",
#         "originalName": "pasta",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fusilli.jpg"
#       },
#       {
#         "id": 5139,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "whole duck",
#         "original": "duck",
#         "originalName": "duck",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/duck.png"
#       },
#       {
#         "id": 10018368,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "dumpling",
#         "original": "dumpling",
#         "originalName": "dumpling",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/puff-pastry-squares.jpg"
#       },
#       {
#         "id": 98924,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Baking",
#         "name": "pizza",
#         "original": "pizza",
#         "originalName": "pizza",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 98905,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Health Foods;Baking",
#         "name": "meal",
#         "original": "meal",
#         "originalName": "meal",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10015121,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "tuna",
#         "original": "tuna",
#         "originalName": "tuna",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/canned-tuna.png"
#       },
#       {
#         "id": 20444,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "rice",
#         "original": "rice",
#         "originalName": "rice",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/uncooked-white-rice.png"
#       },
#       {
#         "id": 19297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "jelly",
#         "original": "jelly",
#         "originalName": "jelly",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/strawberry-jam.png"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "noodle",
#         "original": "noodle",
#         "originalName": "noodle",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fusilli.jpg"
#       },
#       {
#         "id": 7071,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "salami",
#         "original": "salami",
#         "originalName": "salami",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salami.jpg"
#       },
#       {
#         "id": 18364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Bakery/Bread;Pasta and Rice;Ethnic Foods",
#         "name": "tortilla",
#         "original": "tortilla",
#         "originalName": "tortilla",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 9431,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "fruit",
#         "original": "fruit",
#         "originalName": "fruit",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-fresh-fruit.jpg"
#       },
#       {
#         "id": 99209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Refrigerated",
#         "name": "dip",
#         "original": "dip",
#         "originalName": "dip",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/onion-dip.png"
#       },
#       {
#         "id": 9195,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "olive",
#         "original": "olive",
#         "originalName": "olive",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/olives-mixed.jpg"
#       },
#       {
#         "id": 9003,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "apple",
#         "original": "apple",
#         "originalName": "apple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/apple.jpg"
#       },
#       {
#         "id": 6997,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "gravy",
#         "original": "gravy",
#         "originalName": "gravy",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/gravy.jpg"
#       },
#       {
#         "id": 99288,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Condiments",
#         "name": "sauce",
#         "original": "sauce",
#         "originalName": "sauce",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/dark-sauce.jpg"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yogurt",
#         "original": "yogurt",
#         "originalName": "yogurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 1077,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "milk",
#         "original": "milk",
#         "originalName": "milk",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/milk.png"
#       },
#       {
#         "id": 11519297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "spread",
#         "original": "spread",
#         "originalName": "spread",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fig-preserves.jpg"
#       },
#       {
#         "id": 93624,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "haloumi",
#         "original": "haloumi",
#         "originalName": "haloumi",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/halloumi.png"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yoghurt",
#         "original": "yoghurt",
#         "originalName": "yoghurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 14209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Tea and Coffee",
#         "name": "coffee",
#         "original": "coffee",
#         "originalName": "coffee",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brewed-coffee.jpg"
#       },
#       {
#         "id": 1017,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cream cheese",
#         "original": "cream cheese",
#         "originalName": "cream cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cream-cheese.jpg"
#       },
#       {
#         "id": 10111143,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "stick",
#         "original": "stick",
#         "originalName": "stick",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/celery.jpg"
#       },
#       {
#         "id": 10151,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "ham",
#         "original": "ham",
#         "originalName": "ham",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/ham-whole.jpg"
#       },
#       {
#         "id": 11124,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "carrot",
#         "original": "carrot",
#         "originalName": "carrot",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/sliced-carrot.png"
#       },
#       {
#         "id": 11583,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen",
#         "name": "vegetable",
#         "original": "vegetable",
#         "originalName": "vegetable",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-vegetables.png"
#       },
#       {
#         "id": 9176,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mango",
#         "original": "mango",
#         "originalName": "mango",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mango.jpg"
#       },
#       {
#         "id": 9037,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "avocado",
#         "original": "avocado",
#         "originalName": "avocado",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/avocado.jpg"
#       },
#       {
#         "id": 9266,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "pineapple",
#         "original": "pineapple",
#         "originalName": "pineapple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pineapple.jpg"
#       },
#       {
#         "id": 98840,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "broccolini",
#         "original": "broccolini",
#         "originalName": "broccolini",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/broccolini.jpg"
#       },
#       {
#         "id": 11282,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "onion",
#         "original": "onion",
#         "originalName": "onion",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-onion.png"
#       },
#       {
#         "id": 11260,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mushroom",
#         "original": "mushroom",
#         "originalName": "mushroom",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mushrooms.png"
#       },
#       {
#         "id": 11529,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "tomato",
#         "original": "tomato",
#         "originalName": "tomato",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/tomato.png"
#       },
#       {
#         "id": 21052,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "salad",
#         "original": "salad",
#         "originalName": "salad",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-greens-or-mesclun.jpg"
#       },
#       {
#         "id": 19109,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Sweet Snacks",
#         "name": "the product is a kit",
#         "original": "the product is a kit or mix for mexican-style food preparation",
#         "originalName": "the product is a kit or mix for mexican-style food preparation",
#         "meta": [
#           "mexican-style",
#           "for  food preparation"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/kit-kat.png"
#       },
#       {
#         "id": 99274,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": null,
#         "name": "so there isn't a clear",
#         "original": "so there isn't a clear",
#         "originalName": "so there isn't a clear",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/no.jpg"
#       },
#       {
#         "id": 10118364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "burrito kit",
#         "original": "the product is a mexican-style taco or burrito kit",
#         "originalName": "the product is a mexican-style taco or burrito kit",
#         "meta": [
#           "mexican-style"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 10072,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "pork shoulder",
#         "original": "pork shoulder",
#         "originalName": "pork shoulder",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pork-shoulder.png"
#       },
#       {
#         "id": 23572,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen;Meat",
#         "name": "beef",
#         "original": "beef",
#         "originalName": "beef",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/beef-cubes-raw.png"
#       },
#       {
#         "id": 10017224,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "lamb",
#         "original": "lamb",
#         "originalName": "lamb",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/lamb-shanks.jpg"
#       },
#       {
#         "id": 15076,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "salmon",
#         "original": "salmon",
#         "originalName": "salmon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salmon.png"
#       },
#       {
#         "id": 10115261,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "fish",
#         "original": "fish",
#         "originalName": "fish",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fish-fillet.jpg"
#       }
#     ],
#     "likes": 1
#   },
#   {
#     "id": 715521,
#     "title": "Turkey Avocado BLT Salad",
#     "image": "https://img.spoonacular.com/recipes/715521-312x231.jpg",
#     "imageType": "jpg",
#     "usedIngredientCount": 5,
#     "missedIngredientCount": 1,
#     "missedIngredients": [
#       {
#         "id": 11165,
#         "amount": 1.0,
#         "unit": "tsp",
#         "unitLong": "teaspoon",
#         "unitShort": "tsp",
#         "aisle": "Spices and Seasonings",
#         "name": "cilantro",
#         "original": "1 tsp Cilantro",
#         "originalName": "Cilantro",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cilantro.png"
#       }
#     ],
#     "usedIngredients": [
#       {
#         "id": 9037,
#         "amount": 1.0,
#         "unit": "small",
#         "unitLong": "small",
#         "unitShort": "small",
#         "aisle": "Produce",
#         "name": "avocado",
#         "original": "1 small Avocado (sliced)",
#         "originalName": "Avocado (sliced)",
#         "meta": [
#           "sliced",
#           "()"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/avocado.jpg"
#       },
#       {
#         "id": 10211529,
#         "amount": 1.0,
#         "unit": "small",
#         "unitLong": "small",
#         "unitShort": "small",
#         "aisle": "Produce",
#         "name": "roma tomato",
#         "original": "1 small Roma tomato (chopped)",
#         "originalName": "Roma tomato (chopped)",
#         "meta": [
#           "chopped",
#           "()"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/roma-tomatoes.png"
#       },
#       {
#         "id": 21052,
#         "amount": 2.0,
#         "unit": "servings",
#         "unitLong": "servings",
#         "unitShort": "servings",
#         "aisle": "Produce",
#         "name": "salad leaves",
#         "original": "Mixed Green Salad leaves",
#         "originalName": "Mixed Green Salad leaves",
#         "meta": [
#           "mixed",
#           "green"
#         ],
#         "extendedName": "green mixed salad leaves",
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-greens-or-mesclun.jpg"
#       },
#       {
#         "id": 10310123,
#         "amount": 2.0,
#         "unit": "",
#         "unitLong": "",
#         "unitShort": "",
#         "aisle": "Meat",
#         "name": "center cut bacon",
#         "original": "(2 pieces) center cut bacon, cooked and chopped",
#         "originalName": "pieces) center cut bacon, cooked and chopped",
#         "meta": [
#           "cooked",
#           "chopped"
#         ],
#         "extendedName": "cooked center cut bacon",
#         "image": "https://img.spoonacular.com/ingredients_100x100/raw-bacon.png"
#       },
#       {
#         "id": 5696,
#         "amount": 0.5,
#         "unit": "cup",
#         "unitLong": "cups",
#         "unitShort": "cup",
#         "aisle": "Meat",
#         "name": "turkey breast",
#         "original": "1/2 cup Turkey breast",
#         "originalName": "Turkey breast",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/turkey-breast.jpg"
#       }
#     ],
#     "unusedIngredients": [
#       {
#         "id": 1123,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "egg",
#         "original": "egg",
#         "originalName": "egg",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/egg.png"
#       },
#       {
#         "id": 18010,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Baking",
#         "name": "baking mix",
#         "original": "baking mix",
#         "originalName": "baking mix",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10118368,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "spring roll",
#         "original": "spring roll",
#         "originalName": "spring roll",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/rice-paper.jpg"
#       },
#       {
#         "id": 5006,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "whole chicken",
#         "original": "chicken",
#         "originalName": "chicken",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/whole-chicken.jpg"
#       },
#       {
#         "id": 5165,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "turkey",
#         "original": "turkey",
#         "originalName": "turkey",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/turkey-raw-whole.jpg"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "pasta",
#         "original": "pasta",
#         "originalName": "pasta",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fusilli.jpg"
#       },
#       {
#         "id": 5139,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "whole duck",
#         "original": "duck",
#         "originalName": "duck",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/duck.png"
#       },
#       {
#         "id": 10018368,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "dumpling",
#         "original": "dumpling",
#         "originalName": "dumpling",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/puff-pastry-squares.jpg"
#       },
#       {
#         "id": 98924,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Baking",
#         "name": "pizza",
#         "original": "pizza",
#         "originalName": "pizza",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 98905,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Health Foods;Baking",
#         "name": "meal",
#         "original": "meal",
#         "originalName": "meal",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10015121,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "tuna",
#         "original": "tuna",
#         "originalName": "tuna",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/canned-tuna.png"
#       },
#       {
#         "id": 20444,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "rice",
#         "original": "rice",
#         "originalName": "rice",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/uncooked-white-rice.png"
#       },
#       {
#         "id": 19297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "jelly",
#         "original": "jelly",
#         "originalName": "jelly",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/strawberry-jam.png"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "noodle",
#         "original": "noodle",
#         "originalName": "noodle",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fusilli.jpg"
#       },
#       {
#         "id": 7071,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "salami",
#         "original": "salami",
#         "originalName": "salami",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salami.jpg"
#       },
#       {
#         "id": 18364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Bakery/Bread;Pasta and Rice;Ethnic Foods",
#         "name": "tortilla",
#         "original": "tortilla",
#         "originalName": "tortilla",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 9431,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "fruit",
#         "original": "fruit",
#         "originalName": "fruit",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-fresh-fruit.jpg"
#       },
#       {
#         "id": 99209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Refrigerated",
#         "name": "dip",
#         "original": "dip",
#         "originalName": "dip",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/onion-dip.png"
#       },
#       {
#         "id": 9195,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "olive",
#         "original": "olive",
#         "originalName": "olive",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/olives-mixed.jpg"
#       },
#       {
#         "id": 9003,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "apple",
#         "original": "apple",
#         "originalName": "apple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/apple.jpg"
#       },
#       {
#         "id": 6997,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "gravy",
#         "original": "gravy",
#         "originalName": "gravy",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/gravy.jpg"
#       },
#       {
#         "id": 99288,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Condiments",
#         "name": "sauce",
#         "original": "sauce",
#         "originalName": "sauce",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/dark-sauce.jpg"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yogurt",
#         "original": "yogurt",
#         "originalName": "yogurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 1077,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "milk",
#         "original": "milk",
#         "originalName": "milk",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/milk.png"
#       },
#       {
#         "id": 1041009,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cheese",
#         "original": "cheese",
#         "originalName": "cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cheddar-cheese.png"
#       },
#       {
#         "id": 1009,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cheddar cheese",
#         "original": "cheddar cheese",
#         "originalName": "cheddar cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cheddar-cheese.png"
#       },
#       {
#         "id": 11519297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "spread",
#         "original": "spread",
#         "originalName": "spread",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fig-preserves.jpg"
#       },
#       {
#         "id": 93624,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "haloumi",
#         "original": "haloumi",
#         "originalName": "haloumi",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/halloumi.png"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yoghurt",
#         "original": "yoghurt",
#         "originalName": "yoghurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 14209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Tea and Coffee",
#         "name": "coffee",
#         "original": "coffee",
#         "originalName": "coffee",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brewed-coffee.jpg"
#       },
#       {
#         "id": 1017,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cream cheese",
#         "original": "cream cheese",
#         "originalName": "cream cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cream-cheese.jpg"
#       },
#       {
#         "id": 10111143,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "stick",
#         "original": "stick",
#         "originalName": "stick",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/celery.jpg"
#       },
#       {
#         "id": 10123,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "bacon",
#         "original": "bacon",
#         "originalName": "bacon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/raw-bacon.png"
#       },
#       {
#         "id": 10151,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "ham",
#         "original": "ham",
#         "originalName": "ham",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/ham-whole.jpg"
#       },
#       {
#         "id": 11124,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "carrot",
#         "original": "carrot",
#         "originalName": "carrot",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/sliced-carrot.png"
#       },
#       {
#         "id": 11583,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen",
#         "name": "vegetable",
#         "original": "vegetable",
#         "originalName": "vegetable",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-vegetables.png"
#       },
#       {
#         "id": 9176,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mango",
#         "original": "mango",
#         "originalName": "mango",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mango.jpg"
#       },
#       {
#         "id": 9266,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "pineapple",
#         "original": "pineapple",
#         "originalName": "pineapple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pineapple.jpg"
#       },
#       {
#         "id": 9050,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "blueberry",
#         "original": "blueberry",
#         "originalName": "blueberry",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/blueberries.jpg"
#       },
#       {
#         "id": 98840,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "broccolini",
#         "original": "broccolini",
#         "originalName": "broccolini",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/broccolini.jpg"
#       },
#       {
#         "id": 11282,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "onion",
#         "original": "onion",
#         "originalName": "onion",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-onion.png"
#       },
#       {
#         "id": 11260,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mushroom",
#         "original": "mushroom",
#         "originalName": "mushroom",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mushrooms.png"
#       },
#       {
#         "id": 19109,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Sweet Snacks",
#         "name": "the product is a kit",
#         "original": "the product is a kit or mix for mexican-style food preparation",
#         "originalName": "the product is a kit or mix for mexican-style food preparation",
#         "meta": [
#           "mexican-style",
#           "for  food preparation"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/kit-kat.png"
#       },
#       {
#         "id": 99274,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": null,
#         "name": "so there isn't a clear",
#         "original": "so there isn't a clear",
#         "originalName": "so there isn't a clear",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/no.jpg"
#       },
#       {
#         "id": 10118364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "burrito kit",
#         "original": "the product is a mexican-style taco or burrito kit",
#         "originalName": "the product is a mexican-style taco or burrito kit",
#         "meta": [
#           "mexican-style"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 10072,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "pork shoulder",
#         "original": "pork shoulder",
#         "originalName": "pork shoulder",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pork-shoulder.png"
#       },
#       {
#         "id": 23572,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen;Meat",
#         "name": "beef",
#         "original": "beef",
#         "originalName": "beef",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/beef-cubes-raw.png"
#       },
#       {
#         "id": 10017224,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "lamb",
#         "original": "lamb",
#         "originalName": "lamb",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/lamb-shanks.jpg"
#       },
#       {
#         "id": 15076,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "salmon",
#         "original": "salmon",
#         "originalName": "salmon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salmon.png"
#       },
#       {
#         "id": 10115261,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "fish",
#         "original": "fish",
#         "originalName": "fish",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fish-fillet.jpg"
#       }
#     ],
#     "likes": 5518
#   },
#   {
#     "id": 663553,
#     "title": "Tomato and Bacon Pizza With Rice Crust",
#     "image": "https://img.spoonacular.com/recipes/663553-312x231.jpg",
#     "imageType": "jpg",
#     "usedIngredientCount": 5,
#     "missedIngredientCount": 2,
#     "missedIngredients": [
#       {
#         "id": 10211821,
#         "amount": 2.0,
#         "unit": "",
#         "unitLong": "",
#         "unitShort": "",
#         "aisle": "Produce",
#         "name": "bell pepper",
#         "original": "2 bell pepper, sliced",
#         "originalName": "bell pepper, sliced",
#         "meta": [
#           "sliced"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/bell-pepper-orange.png"
#       },
#       {
#         "id": 1022027,
#         "amount": 1.0,
#         "unit": "teaspoon",
#         "unitLong": "teaspoon",
#         "unitShort": "tsp",
#         "aisle": "Spices and Seasonings",
#         "name": "seasoning",
#         "original": "1 teaspoon Italian seasoning, optional",
#         "originalName": "Italian seasoning, optional",
#         "meta": [
#           "italian"
#         ],
#         "extendedName": "italian seasoning",
#         "image": "https://img.spoonacular.com/ingredients_100x100/dried-herbs.png"
#       }
#     ],
#     "usedIngredients": [
#       {
#         "id": 10220445,
#         "amount": 2.0,
#         "unit": "cups",
#         "unitLong": "cups",
#         "unitShort": "cup",
#         "aisle": "Pasta and Rice",
#         "name": "rice",
#         "original": "2 cups cooked rice",
#         "originalName": "cooked rice",
#         "meta": [
#           "cooked"
#         ],
#         "extendedName": "cooked rice",
#         "image": "https://img.spoonacular.com/ingredients_100x100/uncooked-white-rice.png"
#       },
#       {
#         "id": 1123,
#         "amount": 1.0,
#         "unit": "",
#         "unitLong": "",
#         "unitShort": "",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "egg",
#         "original": "1 egg",
#         "originalName": "egg",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/egg.png"
#       },
#       {
#         "id": 1001026,
#         "amount": 2.0,
#         "unit": "cups",
#         "unitLong": "cups",
#         "unitShort": "cup",
#         "aisle": "Cheese",
#         "name": "mozzarella cheese",
#         "original": "2 cups mozzarella cheese, shredded",
#         "originalName": "mozzarella cheese, shredded",
#         "meta": [
#           "shredded"
#         ],
#         "extendedName": "shredded mozzarella cheese",
#         "image": "https://img.spoonacular.com/ingredients_100x100/shredded-cheese-white.jpg"
#       },
#       {
#         "id": 11529,
#         "amount": 3.0,
#         "unit": "",
#         "unitLong": "",
#         "unitShort": "",
#         "aisle": "Produce",
#         "name": "tomatoes",
#         "original": "3 tomatoes",
#         "originalName": "tomatoes",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/tomato.png"
#       },
#       {
#         "id": 42130,
#         "amount": 6.0,
#         "unit": "strips",
#         "unitLong": "strips",
#         "unitShort": "strips",
#         "aisle": "Meat",
#         "name": "at least of turkey bacon",
#         "original": "At least 6 strips of turkey bacon, cut into 2 inch pieces",
#         "originalName": "At least of turkey bacon, cut into 2 inch pieces",
#         "meta": [
#           "cut into 2 inch pieces"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/bacon-turkey.jpg"
#       }
#     ],
#     "unusedIngredients": [
#       {
#         "id": 18010,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Baking",
#         "name": "baking mix",
#         "original": "baking mix",
#         "originalName": "baking mix",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10118368,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "spring roll",
#         "original": "spring roll",
#         "originalName": "spring roll",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/rice-paper.jpg"
#       },
#       {
#         "id": 5006,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "whole chicken",
#         "original": "chicken",
#         "originalName": "chicken",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/whole-chicken.jpg"
#       },
#       {
#         "id": 5165,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "turkey",
#         "original": "turkey",
#         "originalName": "turkey",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/turkey-raw-whole.jpg"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
# ...
#         "originalName": "pizza",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 98905,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Health Foods;Baking",
#         "name": "meal",
#         "original": "meal",
#         "originalName": "meal",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-flour.jpg"
#       },
#       {
#         "id": 10015121,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "tuna",
#         "original": "tuna",
#         "originalName": "tuna",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/canned-tuna.png"
#       },
#       {
#         "id": 20444,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "rice",
#         "original": "rice",
#         "originalName": "rice",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/uncooked-white-rice.png"
#       },
#       {
#         "id": 19297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "jelly",
#         "original": "jelly",
#         "originalName": "jelly",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/strawberry-jam.png"
#       },
#       {
#         "id": 20420,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Pasta and Rice",
#         "name": "noodle",
#         "original": "noodle",
#         "originalName": "noodle",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fusilli.jpg"
#       },
#       {
#         "id": 7071,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "salami",
#         "original": "salami",
#         "originalName": "salami",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salami.jpg"
#       },
#       {
#         "id": 18364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Bakery/Bread;Pasta and Rice;Ethnic Foods",
#         "name": "tortilla",
#         "original": "tortilla",
#         "originalName": "tortilla",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 9431,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "fruit",
#         "original": "fruit",
#         "originalName": "fruit",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-fresh-fruit.jpg"
#       },
#       {
#         "id": 99209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Refrigerated",
#         "name": "dip",
#         "original": "dip",
#         "originalName": "dip",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/onion-dip.png"
#       },
#       {
#         "id": 9195,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "olive",
#         "original": "olive",
#         "originalName": "olive",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/olives-mixed.jpg"
#       },
#       {
#         "id": 9003,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "apple",
#         "original": "apple",
#         "originalName": "apple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/apple.jpg"
#       },
#       {
#         "id": 6997,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Canned and Jarred",
#         "name": "gravy",
#         "original": "gravy",
#         "originalName": "gravy",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/gravy.jpg"
#       },
#       {
#         "id": 99288,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Condiments",
#         "name": "sauce",
#         "original": "sauce",
#         "originalName": "sauce",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/dark-sauce.jpg"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yogurt",
#         "original": "yogurt",
#         "originalName": "yogurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 1077,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "milk",
#         "original": "milk",
#         "originalName": "milk",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/milk.png"
#       },
#       {
#         "id": 1009,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cheddar cheese",
#         "original": "cheddar cheese",
#         "originalName": "cheddar cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cheddar-cheese.png"
#       },
#       {
#         "id": 11519297,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Nut butters, Jams, and Honey",
#         "name": "spread",
#         "original": "spread",
#         "originalName": "spread",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fig-preserves.jpg"
#       },
#       {
#         "id": 93624,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "haloumi",
#         "original": "haloumi",
#         "originalName": "haloumi",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/halloumi.png"
#       },
#       {
#         "id": 1116,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Milk, Eggs, Other Dairy",
#         "name": "yoghurt",
#         "original": "yoghurt",
#         "originalName": "yoghurt",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/plain-yogurt.jpg"
#       },
#       {
#         "id": 14209,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Tea and Coffee",
#         "name": "coffee",
#         "original": "coffee",
#         "originalName": "coffee",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brewed-coffee.jpg"
#       },
#       {
#         "id": 1017,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Cheese",
#         "name": "cream cheese",
#         "original": "cream cheese",
#         "originalName": "cream cheese",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/cream-cheese.jpg"
#       },
#       {
#         "id": 10111143,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "stick",
#         "original": "stick",
#         "originalName": "stick",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/celery.jpg"
#       },
#       {
#         "id": 10123,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "bacon",
#         "original": "bacon",
#         "originalName": "bacon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/raw-bacon.png"
#       },
#       {
#         "id": 10151,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "ham",
#         "original": "ham",
#         "originalName": "ham",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/ham-whole.jpg"
#       },
#       {
#         "id": 11124,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "carrot",
#         "original": "carrot",
#         "originalName": "carrot",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/sliced-carrot.png"
#       },
#       {
#         "id": 11583,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen",
#         "name": "vegetable",
#         "original": "vegetable",
#         "originalName": "vegetable",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-vegetables.png"
#       },
#       {
#         "id": 9176,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mango",
#         "original": "mango",
#         "originalName": "mango",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mango.jpg"
#       },
#       {
#         "id": 9266,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "pineapple",
#         "original": "pineapple",
#         "originalName": "pineapple",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pineapple.jpg"
#       },
#       {
#         "id": 9050,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "blueberry",
#         "original": "blueberry",
#         "originalName": "blueberry",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/blueberries.jpg"
#       },
#       {
#         "id": 98840,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "broccolini",
#         "original": "broccolini",
#         "originalName": "broccolini",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/broccolini.jpg"
#       },
#       {
#         "id": 11282,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "onion",
#         "original": "onion",
#         "originalName": "onion",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/brown-onion.png"
#       },
#       {
#         "id": 11260,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "mushroom",
#         "original": "mushroom",
#         "originalName": "mushroom",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mushrooms.png"
#       },
#       {
#         "id": 21052,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Produce",
#         "name": "salad",
#         "original": "salad",
#         "originalName": "salad",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/mixed-greens-or-mesclun.jpg"
#       },
#       {
#         "id": 19109,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Sweet Snacks",
#         "name": "the product is a kit",
#         "original": "the product is a kit or mix for mexican-style food preparation",
#         "originalName": "the product is a kit or mix for mexican-style food preparation",
#         "meta": [
#           "mexican-style",
#           "for  food preparation"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/kit-kat.png"
#       },
#       {
#         "id": 99274,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": null,
#         "name": "so there isn't a clear",
#         "original": "so there isn't a clear",
#         "originalName": "so there isn't a clear",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/no.jpg"
#       },
#       {
#         "id": 10118364,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Ethnic Foods",
#         "name": "burrito kit",
#         "original": "the product is a mexican-style taco or burrito kit",
#         "originalName": "the product is a mexican-style taco or burrito kit",
#         "meta": [
#           "mexican-style"
#         ],
#         "image": "https://img.spoonacular.com/ingredients_100x100/flour-tortilla.jpg"
#       },
#       {
#         "id": 10072,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "pork shoulder",
#         "original": "pork shoulder",
#         "originalName": "pork shoulder",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/pork-shoulder.png"
#       },
#       {
#         "id": 23572,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Frozen;Meat",
#         "name": "beef",
#         "original": "beef",
#         "originalName": "beef",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/beef-cubes-raw.png"
#       },
#       {
#         "id": 10017224,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Meat",
#         "name": "lamb",
#         "original": "lamb",
#         "originalName": "lamb",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/lamb-shanks.jpg"
#       },
#       {
#         "id": 15076,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "salmon",
#         "original": "salmon",
#         "originalName": "salmon",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/salmon.png"
#       },
#       {
#         "id": 10115261,
#         "amount": 1.0,
#         "unit": "serving",
#         "unitLong": "serving",
#         "unitShort": "serving",
#         "aisle": "Seafood",
#         "name": "fish",
#         "original": "fish",
#         "originalName": "fish",
#         "meta": [],
#         "image": "https://img.spoonacular.com/ingredients_100x100/fish-fillet.jpg"
#       }
#     ],
#     "likes": 1
#   }
# ]
