# %% [markdown]
# ### Imports

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time

# %% [markdown]
# ### Woolworths weekly catalogue scraper

# %%
# api endpoint to get category list (use "view" endpoint)
url_view = "https://embed.salefinder.com.au/productlist/view/62222/"

# parameters for the request
params = {
    'locationId': '4679',
    'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
    'saleGroup': '0',
    'rows_per_page': '10',
}

# headers to make our request look like a real browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
    'Accept': '*/*',
}

# fetch the main catalogue page
response = requests.get(url_view, params=params, headers=headers)
json_text = response.text.strip()[1:-1]
data = json.loads(json_text)

print(f"Fetched: {data['saleName']}")
print(f"Valid: {data['startDate']} to {data['endDate']}\n")

# parse the HTML to extract categories
soup = BeautifulSoup(data['content'], 'html.parser')
categories = {}

for link in soup.find_all('a', class_='sf-navcategory-link'):
    href = link.get('href', '')
    if 'categoryId=' in href:
        category_id = href.split('categoryId=')[1].split('&')[0]
        category_name = link.text.strip()
        categories[category_id] = category_name
# Out:
# Fetched: Weekly Catalogue NSW
# Valid: 2025-11-19T00:00:00 to 2025-11-25T23:59:59

# %%
url_category = "https://embed.salefinder.com.au/productlist/category/62222/"

# list to store ALL products from ALL categories
all_products = []

# loop through each category
for category_id, category_name in categories.items():
    print(f"Scraping {category_name}...", end=" ")
    
    # parameters for this specific category
    params = {
        'locationId': '4679',
        'token': '570f5c4a44505b5f51477f531a03180a0e0b1c1362352b2e21363226253968717d7a787d6468626562612b',
        'saleGroup': '0',
        'categoryId': category_id, 
        'rows_per_page': '500',
    }
    
    # api request
    response = requests.get(url_category, params=params, headers=headers)
    json_text = response.text.strip()[1:-1]
    data = json.loads(json_text)
    
    # parse
    soup = BeautifulSoup(data['content'], 'html.parser')
    
    # extract products
    for product in soup.find_all('div', class_='shelfProductStamp'):
        name_tag = product.find('span', class_='sf-item-heading')
        sale_price_tag = product.find('span', class_='sf-pricedisplay')
        savings_tag = product.find('span', class_='sf-regprice')
        
        if not name_tag or not sale_price_tag:
            continue
        
        name = name_tag.text.strip()
        sale_price = sale_price_tag.text.strip()
        stock_code = product.get('data-stockcode')
        
        sale_value = float(sale_price.replace('$', '').replace(',', ''))    
            
        if savings_tag:
            savings = savings_tag.text.strip()
            savings_value = float(savings.replace('$', ''))
            original_value = sale_value + savings_value
        else:
            savings_value = 0.0
            original_value = sale_value
        
        all_products.append({
            'category': category_name,
            'stock_code': stock_code,
            'name': name,
            'sale_price': sale_value,
            'original_price': original_value,
            'savings': savings_value
        })
    
    print(f"{len([p for p in all_products if p['category'] == category_name])} products")
    time.sleep(0.3) 

# Create DataFrame
df = pd.DataFrame(all_products)
# Out:
# Scraping Baby... 6 products
# Scraping Bakery... 22 products
# Scraping Baking... 8 products
# Scraping Beauty... 64 products
# Scraping Biscuits & Snacks... 17 products
# Scraping Breakfast Foods... 8 products
# Scraping Canned & Packet food... 21 products
# Scraping Clothing... 4 products
# Scraping Condiments... 14 products
# Scraping Confectionery... 14 products
# Scraping Cooking, Seasoning & Gravy... 6 products
# Scraping Dairy... 16 products
# Scraping Deli & Chilled... 31 products
# Scraping Desserts... 1 products
# Scraping Drinks... 31 products
# Scraping Frozen Food... 30 products
# Scraping Fruit & Vegetables... 19 products
# Scraping Health & Wellbeing... 77 products
# Scraping Health Foods... 4 products
# Scraping Home & Outdoor... 45 products
# Scraping Household Cleaning... 8 products
# Scraping Jams & Spreads... 4 products
# Scraping Meat... 32 products
# Scraping Papergoods, Wraps & Bags... 3 products
# Scraping Pet care... 10 products
# Scraping Seafood... 8 products
# Scraping Stationery & Media... 14 products
# Scraping Toiletries... 22 products

# %%
df = pd.DataFrame(all_products)

df.groupby('category').first().reset_index()
# Out:
#                       category stock_code  \
# 0                         Baby     612568
# 1                       Bakery    6044304
# 2                       Baking      37736
# 3                       Beauty    6036022
# 4            Biscuits & Snacks     956027
# 5              Breakfast Foods     199725
# 6         Canned & Packet food     666347
# 7                     Clothing     282756
# 8                   Condiments     923892
# 9                Confectionery     320104
# 10  Cooking, Seasoning & Gravy    6049885
# 11                       Dairy       6576
# 12              Deli & Chilled     923892
# 13                    Desserts     605303
# 14                      Drinks     724514
# 15                 Frozen Food     767652
# 16          Fruit & Vegetables     143168
# 17          Health & Wellbeing    6036022
# 18                Health Foods      57855
# 19              Home & Outdoor     325132
# 20          Household Cleaning     215125
# 21              Jams & Spreads     142574
# 22                        Meat     764979
# 23    Papergoods, Wraps & Bags     574728
# 24                    Pet care      88204
# 25                     Seafood      46119
# 26          Stationery & Media     223427
# 27                  Toiletries    6021193
#
#                                                  name  sale_price  \
# 0   Tommee Tippee Night Time Soothers 18-36m Assor...        7.20
# 1                       35hr Sourdough Baguette Pk 2#        3.50
# 2                           CSR Dark Brown Sugar 1 kg        4.60
# 3   Little Urchin SPF 50+ Face Natural Clear Zinc ...       12.50
# 4                         Sakata Rice Crackers 80-90g        1.25
# 5   Kellogg’s Nutri Grain 765g or Coco Pops Cereal...        6.00
# 6   Woolworths Antipasto Varieties 110-135g – From...        6.50
# 7   Bonds Men’s Cushioned 1/4 Crew Sock Assorted Pk 3        8.00
# 8                   Obela Dips 220g – From the Fridge        4.00
# 9                          Cadbury Medium Bars 30-55g        1.20
# 10                                   Maggi Gravy 1 kg       12.50
# 11  King Island Brie or Camembert Varieties 175-20...        9.90
# 12                  Obela Dips 220g – From the Fridge        4.00
# 13           Woolworths Chocolate Sponge Pudding 500g        8.00
# 14                    Cocobella Coconut Water 1 Litre        2.75
# 15  Ingham’s Turkey Easy Carve Buffe^ – From the F...        9.50
# 16                            Australian R2E2 Mangoes        3.00
# 17  Little Urchin SPF 50+ Face Natural Clear Zinc ...       12.50
# 18  Vege Chips or Crackers Multipack 180-250g Pk 1...        7.60
# 19     Bushman Heavy Duty Insect Repellent Spray 225g       13.25
# 20              Vanish Gold Stain Remover Powder 2 kg       16.00
# 21              Queen Pure Canadian Maple Syrup 250ml        9.50
# 22                          Australian Lamb Leg Roast       14.00
# 23         Quilton Tuffy White 4 Ply Paper Towel Pk 3        3.50
# 24                   Whiskas Wet Cat Food Pk 12 x 85g        7.50
# 25  Thawed Extra Large Cooked Australian Tiger Prawns       28.00
# 26         Quantum Alkaline Batteries AA or AAA Pk 16        9.50
# 27   Billie Malibu or Sparkle Razor Blade Starter Kit        7.50
#
#     original_price  savings
# 0            12.00     4.80
# 1             4.00     0.50
# 2             4.60     0.00
# 3            25.00    12.50
# 4             2.50     1.25
# 5            10.80     4.80
# 6             7.50     1.00
# 7            16.00     8.00
# 8             5.00     1.00
# 9             3.00     1.80
# 10           12.50     0.00
# 11           14.90     5.00
# 12            5.00     1.00
# 13            8.00     0.00
# 14            5.50     2.75
# 15            9.50     0.00
# 16            3.00     0.00
# 17           25.00    12.50
# 18            9.50     1.90
# 19           18.95     5.70
# 20           32.00    16.00
# 21            9.50     0.00
# 22           17.00     3.00
# 23            5.00     1.50
# 24           13.00     5.50
# 25           39.00    11.00
# 26           19.00     9.50
# 27           15.00     7.50

# %%
df['category'].unique()
# Out:
# array(['Baby', 'Bakery', 'Baking', 'Beauty', 'Biscuits & Snacks',
#        'Breakfast Foods', 'Canned & Packet food', 'Clothing',
#        'Condiments', 'Confectionery', 'Cooking, Seasoning & Gravy',
#        'Dairy', 'Deli & Chilled', 'Desserts', 'Drinks', 'Frozen Food',
#        'Fruit & Vegetables', 'Health & Wellbeing', 'Health Foods',
#        'Home & Outdoor', 'Household Cleaning', 'Jams & Spreads', 'Meat',
#        'Papergoods, Wraps & Bags', 'Pet care', 'Seafood',
#        'Stationery & Media', 'Toiletries'], dtype=object)

# %% [markdown]
# ### Australia food guidelines

# %% [markdown]
# https://www.eatforhealth.gov.au/food-essentials/how-much-do-we-need-each-day/recommended-number-serves-adults

# %%
# converting the table above into a df
dietary_guidelines = {
    'Group': [
        'Men 19-50',
        'Men 51-70', 
        'Men 70+',
        'Women 19-50',
        'Women 51-70',
        'Women 70+',
        'Pregnant',
        'Lactating'
    ],
    'Vegetables & Legumes': [6, 5.5, 5, 5, 5, 5, 5, 7.5],
    'Fruit': [2, 2, 2, 2, 2, 2, 2, 2],
    'Grains (Wholegrain)': [6, 6, 4.5, 6, 4, 3, 8.5, 9],
    'Lean Meat & Alternatives': [3, 2.5, 2.5, 2.5, 2, 2, 3.5, 2.5],
    'Dairy (Reduced Fat)': [2.5, 2.5, 3.5, 2.5, 4, 4, 2.5, 2.5],
    'Additional Serves Range': ['0-3', '0-2.5', '0-2.5', '0-2.5', '0-2.5', '0-2', '0-2.5', '0-2.5']
}

df_guidelines = pd.DataFrame(dietary_guidelines)

df_guidelines
# Out:
#          Group  Vegetables & Legumes  Fruit  Grains (Wholegrain)  \
# 0    Men 19-50                   6.0      2                  6.0
# 1    Men 51-70                   5.5      2                  6.0
# 2      Men 70+                   5.0      2                  4.5
# 3  Women 19-50                   5.0      2                  6.0
# 4  Women 51-70                   5.0      2                  4.0
# 5    Women 70+                   5.0      2                  3.0
# 6     Pregnant                   5.0      2                  8.5
# 7    Lactating                   7.5      2                  9.0
#
#    Lean Meat & Alternatives  Dairy (Reduced Fat) Additional Serves Range
# 0                       3.0                  2.5                     0-3
# 1                       2.5                  2.5                   0-2.5
# 2                       2.5                  3.5                   0-2.5
# 3                       2.5                  2.5                   0-2.5
# 4                       2.0                  4.0                   0-2.5
# 5                       2.0                  4.0                     0-2
# 6                       3.5                  2.5                   0-2.5
# 7                       2.5                  2.5                   0-2.5

# %% [markdown]
# ### Categorising sale items into the australian reccomended food groups

# %%
import gensim.downloader as api
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# glove model
model = api.load('glove-wiki-gigaword-300')

# define non-food categories to ignore
NON_FOOD_CATEGORIES = [
    'Baby', 'Beauty', 'Toiletries', 'Household Cleaning', 
    'Home & Outdoor', 'Stationery & Media', 'Clothing', 'Pet care'
]

# define dietary guideline categories with some additional keywords
dietary_guidelines = {
    'Vegetables & Legumes': ['vegetables', 'vegetable', 'legumes', 'beans', 'peas', 'broccoli', 'carrot', 'salad', 'greens'],
    'Fruit': ['fruit', 'fruits', 'apple', 'banana', 'orange', 'berry', 'grape', 'melon'],
    'Grains (Wholegrain)': ['bread', 'rice', 'pasta', 'noodles', 'cereal', 'oats', 'grain', 'wheat', 'crackers', 'muffin', 'bagel', 'bun', 'roll', 'wrap', 'pita', 'tortilla'],
    'Lean Meat & Alternatives': ['meat', 'beef', 'chicken', 'pork', 'lamb', 'fish', 'salmon', 'tuna', 'eggs', 'pie', 'sausage', 'bacon', 'ham', 'protein'],
    'Dairy (Reduced Fat)': ['milk', 'cheese', 'yoghurt', 'yogurt', 'dairy', 'cream', 'butter'],
    'Discretionary': ['chocolate', 'candy', 'chips', 'biscuits', 'cookies', 'cake', 'icecream', 'soft-drink', 'lollies', 'snack']
}

def get_text_embedding(words):
    """
    convert a list of words into a single vector by averaging
    """
    vectors = []
    for word in words:
        word_clean = word.lower().strip()
        if word_clean in model:
            vectors.append(model[word_clean])
    
    if vectors:
        return np.mean(vectors, axis=0)
    else:
        return np.zeros(300)

def classify_product(woolworths_category, product_name):
    """
    combine Woolworths category + product name to classify into dietary guidelines
    """
    # check if this is a non-food category first
    if woolworths_category in NON_FOOD_CATEGORIES:
        return 'Non-Food', 1.0
    
    # combine category and product name into words
    combined_text = f"{woolworths_category} {product_name}"
    
    # tokenize
    words = []
    for word in combined_text.split():
        # remove numbers and short words
        if len(word) > 2 and not word.isdigit():
            words.append(word)
    
    # get embedding for this product
    product_embedding = get_text_embedding(words)
    
    # get embeddings for each dietary category
    best_category = None
    best_score = -1
    
    for category_name, keywords in dietary_guidelines.items():
        category_embedding = get_text_embedding(keywords)
        
        # calculate similarity
        similarity = cosine_similarity(
            product_embedding.reshape(1, -1),
            category_embedding.reshape(1, -1)
        )[0][0]
        
        if similarity > best_score:
            best_score = similarity
            best_category = category_name
    
    return best_category, best_score

# %%
df['dietary_category'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[0],
    axis=1
)

df['dietary_confidence'] = df.apply(
    lambda row: classify_product(row['category'], row['name'])[1],
    axis=1
)

# %%
df_food = df[df['dietary_category'] != 'Non-Food']
df_food.to_csv('food_items_classified_manual_inspect.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category              category stock_code  \
# 0       Dairy (Reduced Fat)                Bakery     159266
# 1             Discretionary                Bakery    6021067
# 2                     Fruit                Bakery     733768
# 3       Grains (Wholegrain)                Bakery    6044304
# 4  Lean Meat & Alternatives     Biscuits & Snacks      71929
# 5      Vegetables & Legumes  Canned & Packet food     335122
#
#                                                 name  sale_price  \
# 0  National Pies Varieties 360g Pk 2 – From the F...        6.80
# 1           Woolworths Chocolate Hazelnut Tarts Pk 6        7.50
# 2                   Apple Turnover with Fresh Cream#        4.50
# 3                      35hr Sourdough Baguette Pk 2#        3.50
# 4  Infuzions Air Fries 90g – From the Health Food...        2.45
# 5                           Always Fresh Olives 240g        4.80
#
#    original_price  savings  dietary_confidence
# 0             8.5     1.70            0.532467
# 1             7.5     0.00            0.737364
# 2             5.0     0.50            0.553427
# 3             4.0     0.50            0.587197
# 4             4.9     2.45            0.545252
# 5            10.8     6.00            0.658829

# %%
test = df_food.groupby('dietary_category').first().reset_index()

# %% [markdown]
# ### Extracting key ingredient

# %%
import anthropic
import time
import os
from dotenv import load_dotenv

load_dotenv() 
client = anthropic.Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY")
)

def extract_key_ingredient_claude(product_name):
    """
    use claude to extract the main ingredient from a product name
    """
    try:
        message = client.messages.create(
            model="claude-3-5-haiku-20241022", 
            max_tokens=20,
            messages=[{
                "role": "user",
                "content": f"""Extract ONLY the main food ingredient from this product name. This ingredient is what best describes the item.  
Return just one to three words in singular form, lowercase, no punctuation.

Examples:
- "Woolworths Free Range Eggs 700g Pk 12" → egg
- "Always Fresh Sicilian Olives Pitted 230g" → olive
- "Four'N Twenty Angus Pies 700g" → beef pie
- "Mr Whisk Vanilla Meringues 130g" → meringue
- "Golden Crumpet Rounds Pk 6" → crumpet
- "Philadelphia Original Cream Cheese Twin Block 500g" → cream cheese 
- "Farmers Union Greek Yogurt Pots 150g" → greek yogurt

Product: {product_name}

Main ingredient:"""
            }]
        )
        
        return message.content[0].text.strip().lower()
    
    except Exception as e:
        print(f"Error processing '{product_name}': {e}")
        return 'Unknown'

results = []
for idx, product_name in enumerate(df_food['name'], 1):
    ingredient = extract_key_ingredient_claude(product_name)
    results.append(ingredient)

df_food['key_ingredient'] = results
# Out:
# C:\Users\ciaod\AppData\Local\Temp\ipykernel_30580\1096676492.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_food['key_ingredient'] = results

# %%
df_food.to_csv('base_table_food.csv', index=False)

# %%
df_food.groupby('dietary_category').first().reset_index()
# Out:
#            dietary_category              category stock_code  \
# 0       Dairy (Reduced Fat)                Bakery     159266
# 1             Discretionary                Bakery    6021067
# 2                     Fruit                Bakery     733768
# 3       Grains (Wholegrain)                Bakery    6044304
# 4  Lean Meat & Alternatives     Biscuits & Snacks      71929
# 5      Vegetables & Legumes  Canned & Packet food     335122
#
#                                                 name  sale_price  \
# 0  National Pies Varieties 360g Pk 2 – From the F...        6.80
# 1           Woolworths Chocolate Hazelnut Tarts Pk 6        7.50
# 2                   Apple Turnover with Fresh Cream#        4.50
# 3                      35hr Sourdough Baguette Pk 2#        3.50
# 4  Infuzions Air Fries 90g – From the Health Food...        2.45
# 5                           Always Fresh Olives 240g        4.80
#
#    original_price  savings  dietary_confidence key_ingredient
# 0             8.5     1.70            0.532467            pie
# 1             7.5     0.00            0.737364  hazelnut tart
# 2             5.0     0.50            0.553427          apple
# 3             4.0     0.50            0.587197      sourdough
# 4             4.9     2.45            0.545252         potato
# 5            10.8     6.00            0.658829          olive

# %% [markdown]
# ### Recipes

# %%
load_dotenv()
API_KEY = os.getenv("SPOONACULAR_API_KEY", "")

BASE_URL = "https://api.spoonacular.com"

# %%
COOKING_CATEGORIES = [
    'Baking', 'Canned & Packet food', 'Condiments',
    'Cooking, Seasoning & Gravy', 'Dairy', 'Deli & Chilled',
    'Fruit & Vegetables', 'International Foods', 'Jams & Spreads',
    'Meat', 'Seafood'
]

df_cooking = df_food[df_food['category'].isin(COOKING_CATEGORIES)]

# %%
ingredients = df_cooking['key_ingredient'].unique()
ingredient_string = ','.join(ingredients)

# api call
response = requests.get(
    f"{BASE_URL}/recipes/findByIngredients",
    params={
        'apiKey': API_KEY,
        'ingredients': ingredient_string,
        'number': 50,
        'ranking': 2
    }
)

# %%
if response.status_code == 200:
    recipes = response.json()
    
    sale_ingredients_list = df_cooking['key_ingredient'].unique()
    
    recipe_data = []
    for recipe in recipes:
        recipe_ingredients = [ing['name'] for ing in recipe['usedIngredients']] + \
                            [ing['name'] for ing in recipe['missedIngredients']]
        
        matched_ingredients = set()
        
        for recipe_ing in recipe_ingredients:
            for sale_ing in sale_ingredients_list:
                if sale_ing in recipe_ing.lower() or recipe_ing.lower() in sale_ing:
                    matched_ingredients.add(sale_ing)
        
        recipe_data.append({
            'recipe_id': recipe['id'],
            'recipe_name': recipe['title'],
            'no_sale_items': len(matched_ingredients),
            'sale_items': list(matched_ingredients),  # Just the key ingredients
            'all_ingredients': recipe_ingredients
        })
    
    df_recipes = pd.DataFrame(recipe_data)
    df_recipes = df_recipes.sort_values('no_sale_items', ascending=False)

# %%
df_recipes
# Out:
#     recipe_id                                        recipe_name  \
# 43     651707                           Mexican Stuffed Potatoes
# 45     645821                               Grilled Potato Skins
# 16     647956  Involtini Di Pollo - Ham and Cheese Stuffed Ch...
# 46     647417                         Hot Cheesy Bacon Party Dip
# 6      633132                              Avocado Chicken Salad
# 9      654373                                       Palak Paneer
# 22    1003670                             Stuffed Chicken Breast
# 0      648303                                 Itty Bitty Burgers
# 7      642583                  Farfalle with Peas, Ham and Cream
# 5      715563                                  Pierogi Casserole
# 20     730914          Basil Infused Balsamic Oven Baked Chicken
# 25     645733                     Grilled Ham and Swiss Sandwich
# 19     715413             Strawberries and Cream Filled Cupcakes
# 29     651956                                Mini eggplant pizza
# 1      637569                                  Cheese Pork Chops
# 10     654879                  Pasta Roses With Zucchini and Ham
# 17     649175                                        Laksa Lemak
# 44     637658           Cheesy Ham and Shrimp Macaroni Au Gratin
# 49     639337             Chorizo, Bacon, Mushroom and Pea Pasta
# 47     642695                               Feta Stuffed Burgers
# 2      656834  Pork Tenderloin Stuffed With Cranberries and Brie
# 48     651840                 Bacon And Bleu Table-For-Two Salad
# 42    1683469                                   fleet flitterers
# 27     646424               Healthier Southern-Style Green Beans
# 13     655601          Penne with Sausage, Tomatoes and Potatoes
# 8      633324                                     Bacon Scallops
# 31     661447                                Square Deviled Eggs
# 41     633950                      Balsamic Vinaigrette Dressing
# 36     638288      Chicken Roll-Ups With Feta Cheese and Arugula
# 14     645348                                   Greek Side Salad
# 3      650901         Maple Glazed Bacon Wrapped Pork Tenderloin
# 12     642585  Farfalle with fresh tomatoes, basil and mozzar...
# 11     642594        Farfalle with Shrimps, Tomatoes Basil Sauce
# 21     649183                 Lamb and Fresh Goat Cheese Roulade
# 37    1056442  How to Make an Amazing Bacon Wrapped Stuffed C...
# 18     633224                     Baby Brie-Topped Potato Slices
# 30     673463                  Slow Cooker Apple Pork Tenderloin
# 28     633852                                     baked tomatoes
# 26     654485                                      Pancake Bites
# 24     651467                             Summer Beet Side Salad
# 23     650132                 Linguine With Chick Peas and Bacon
# 4      645419  Green Beans With Roasted Walnuts and Sweet Cra...
# 15     636743          Cajun Shrimp and Marinated Cucumber Salad
# 32     632252                    Alouette® Stuffed Mushroom Caps
# 39     644958  Goat Cheese Stuffed Bacon Wrapped Jalapeno App...
# 35     655589                   Penne with Goat Cheese and Basil
# 34     658491       Roasted Asparagus With Bacon and Feta Cheese
# 33     631757  Savory Slow Roasted Tomatoes with Filet of Anc...
# 40     642621                            Feta and Cucumber Saute
# 38     650180                Little phyllo cakes with blackberry
#
#     no_sale_items                                         sale_items  \
# 43              9  [tomato, avocado, cream cheese, potato, cheese...
# 45              8  [cream cheese, potato, cheese, cream, butter, ...
# 16              7  [cream cheese, cheese, butter, chicken breast,...
# 46              7  [tomato, cream cheese, mayonnaise, cheese, cre...
# 6               7  [tomato, avocado, cherry, mayonnaise, salad, c...
# 9               7  [tomato, cream cheese, tomato sauce, cheese, b...
# 22              6  [cream cheese, cheese, cream, chicken breast, ...
# 0               6      [tomato, cheese, mustard, beef, ham, spinach]
# 7               6           [cheese, pea, cream, butter, pasta, ham]
# 5               6  [potato, cheese, butter, milk, noodle, cheddar...
# 20              5  [tomato, tomato sauce, cheese, chicken breast,...
# 25              5     [shortbread, cheese, gingerbread, butter, ham]
# 19              5        [cream cheese, cheese, cream, butter, milk]
# 29              5  [tomato, cream cheese, tomato sauce, cheese, c...
# 1               5             [cheese, cream, pork, butter, mustard]
# 10              5             [cheese, butter, sprinkle, pasta, ham]
# 17              5              [cucumber, gravy, bean, noodle, rice]
# 44              5              [mushroom, cheese, cream, pasta, ham]
# 49              5             [mushroom, pea, pasta, bacon, chorizo]
# 47              5               [tomato, cheese, beef, ham, spinach]
# 2               4               [pork, maple syrup, cheese, mustard]
# 48              4                    [bacon, spinach, apple, cheese]
# 42              4              [cream, cream cheese, butter, cheese]
# 27              4                  [bean, butter, bacon, green bean]
# 13              4                    [tomato, butter, potato, pasta]
# 8               4               [cream, maple syrup, bacon, mustard]
# 31              4                 [cream, cream cheese, ham, cheese]
# 41              3                    [greek yogurt, yogurt, mustard]
# 36              3                  [chicken breast, chicken, cheese]
# 14              3                          [tomato, cucumber, olive]
# 3               3                         [pork, maple syrup, bacon]
# 12              3                            [tomato, butter, pasta]
# 11              3                            [tomato, butter, pasta]
# 21              3                            [lamb, spinach, cheese]
# 37              3                   [chicken breast, chicken, bacon]
# 18              3                           [tomato, potato, cheese]
# 30              3                                [pork, apple, beef]
# 28              3                             [tomato, cheese, milk]
# 26              3                       [maple syrup, butter, bacon]
# 24              3                   [tomato, tomato sauce, cucumber]
# 23              3                               [bacon, cheese, pea]
# 4               2                                 [bean, green bean]
# 15              2                              [cucumber, seasoning]
# 32              2                                [mushroom, spinach]
# 39              2                                    [cheese, bacon]
# 35              2                                    [cheese, pasta]
# 34              2                                    [cheese, bacon]
# 33              1                                           [tomato]
# 40              1                                         [cucumber]
# 38              1                                       [blackberry]
#
#                                       all_ingredients
# 43  [extra beef, salsa, yukon gold potatoes, chedd...
# 45  [baking potatoes, bacon, finely-chopped ham, c...
# 16  [long and chicken breasts, ham, cheese, butter...
# 46  [bacon, cream cheese, mayo, cheddar cheese), r...
# 6   [avocados, cherry tomatoes, mayonnaise, salad,...
# 9   [spoon butter, cheese, garam masala, spinach, ...
# 22  [chicken seasoning, cream cheese, chicken brea...
# 0   [a handful of baby spinach, grape tomatoes, ha...
# 7   [butter, ham, farfalle pasta, heavy cream, par...
# 5   [butter, milk, sharp cheddar cheese, potatoes,...
# 20  [chicken breast, m zarella cheese, tomato, bal...
# 25         [pats of butter, ham, swiss cheese, bread]
# 19              [cream cheese, milk, butter, vanilla]
# 29        [tomato sauce, cheese, pepperoni, eggplant]
# 1   [dijon mustard, gruyere cheese, heavy cream, p...
# 10  [butter, fontina cheese in thinnest pos, ham i...
# 17  [shrimp, laksa gravy, think round rice noodles...
# 44  [elbow pasta, ham, big shitake mushrooms, parm...
# 49  [bacon, chorizo links, mushrooms, pasta, garli...
# 47  [feta cheese, hamburger buns, ground beef, spi...
# 2   [pork tenderloin, cranberries, brie cheese, ma...
# 48  [baby spinach leaves, bleu cheese, bacon, gran...
# 42            [butter, cream cheese, vanilla extract]
# 27                [green beans, butter, bacon, onion]
# 13  [butter, canned tomatoes, penne pasta, potatoe...
# 8   [bacon, sea scallops, whipping cream, dijon mu...
# 31                          [cream cheese, ham, eggs]
# 41          [yogurt, dijon mustard, balsamic vinegar]
# 36  [chicken breast cutlets, feta cheese, baby aru...
# 14  [cucumber, greek feta, kalamata olives, tomato...
# 3              [pork tenderloins, bacon, maple syrup]
# 12  [farfalle pasta by barilla, mozzarella, tomato...
# 11  [butter, farfalle pasta by barilla, shrimps, t...
# 21    [goat cheese, lamb loins, baby spinach, garlic]
# 37  [wright brand hickory bacon, chicken breasts, ...
# 18  [alouette baby brie cheese, parmesan cheese, s...
# 30     [apple r, apples, pork tenderloin, beef broth]
# 28  [tomatoes, unripened goat's milk cheese, parme...
# 26  [add-ins - i used of bacon fbatch of 12 pancak...
# 24                 [beets, cucumber, tomato, parsley]
# 23       [asiago cheese, bacon, linguini, chick peas]
# 4                 [green beans, roasted, cranberries]
# 15  [shrimp, creole seasoning, cucumber, pico de g...
# 32  [mushroom caps, alouette spinach & artichoke s...
# 39                    [bacon, goat cheese, jalapenos]
# 35           [penne pasta, goat cheese, basil leaves]
# 34                    [bacon, feta cheese, asparagus]
# 33  [round tomatoes, anchovy filets, any herbs you...
# 40                   [cucumbers, alouette feta, dill]
# 38             [mascarpone, blackberry, phyllo dough]
